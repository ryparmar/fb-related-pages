# %% [markdown]
# # Page Classfication
#
# The goal of this notebook is to classify pages into 2 classes - clima-related; non-clima based on cca 20-40 last posts. Initialy there were 10 pro-clima (believe in climate change) pages and 10 anti-clima pages (not believing in climate change).

# %%
import json
import spacy
from collections import Counter
from tqdm.notebook import tqdm
import random

# %% [markdown]
# ### Load pages splitted by the root page class affinity

# %%
pos_pages = [i.strip().split('/')[-1] 
             for i in open('/home/spaceape/projects/kaca-dp/data/split_positive_uniq.csv').readlines()]
neg_pages = [i.strip().split('/')[-1] 
             for i in open('/home/spaceape/projects/kaca-dp/data/split_negative_uniq.csv').readlines()]

# %%
print(f"positive: {len(pos_pages)}\nnegative: {len(neg_pages)}")
# Out:
# positive: 1819
# negative: 1936

# %%
pos = ['NASAClimateChange',
       'acespace', 'greenpeace.international',
       'ClimateChangeIsReal', 'climatereality',
       'ClimateChangeNews', 'NatureClimateChange',
       'ClimateChangeCauses', 'GlobalwarmingEva']

neg = ['cfact',
       'iloveco2', 'ClimateChangeLIES',
       'australianclimatemadness', 'ClimateDepot',
       'ccdispatch', 'TheCO2Coalition',
       'Global-Warming-Climate-Change-whatever-its-called-is-a-scam-241741379521',
       'Global-Climate-Scam-1392664020945768']

selected_pages = pos + neg

def append_related(source, target):
    for i in source.split(';'):
        if i.strip():
            target.append(i.strip())
    return target

with open('data/data1.csv', 'r') as f1:
    for i, line in enumerate(f1.readlines()):
        init_page = line.split(';', 1)[0].strip()
        if init_page in selected_pages:
            if line.strip():
                selected_pages.append(line.strip())
            selected_pages = append_related(line, selected_pages)

with open('data/data2-uniq.csv', 'r') as f2:
    for i, line in enumerate(f2.readlines()):
        init_page = line.split(';', 1)[0].strip()
        if init_page in selected_pages:
            if line.strip():
                selected_pages.append(line.strip())
            selected_pages = append_related(line, selected_pages)

# %%
selected_pages = sorted(list(set(selected_pages)))

# %%
len(selected_pages)
# Out:
# 3635

# %%
print(f"positive: {len(pos_pages)}    negative: {len(neg_pages)}")
# Out:
# positive: 1819    negative: 1936

# %% [markdown]
# ### Load posts

# %%
posts0 = json.load(open('/home/spaceape/projects/kaca-dp/data/data-posts-0.json'))
posts1 = json.load(open('/home/spaceape/projects/kaca-dp/data/data-posts-1.json'))

posts2_pos = json.load(open('/home/spaceape/projects/kaca-dp/data/data-posts-pos-2.json'))
posts2_neg = json.load(open('/home/spaceape/projects/kaca-dp/data/data-posts-neg-2.json'))

# %%
posts0.keys()
# Out:
# dict_keys(['cfact', 'ClimateChangeIsNatural', 'iloveco2', 'ClimateChangeLIES', 'australianclimatemadness', 'ClimateDepot', 'ccdispatch', 'TheCO2Coalition', 'Global-Warming-Climate-Change-whatever-its-called-is-a-scam-241741379521', 'Global-Climate-Scam-1392664020945768', 'greenpeace.international', 'NASAClimateChange', 'bloomberggreen', 'acespace', 'ClimateChangeIsReal', 'climatereality', 'ClimateChangeNews', 'NatureClimateChange', 'ClimateChangeCauses', 'GlobalwarmingEva'])

# %%
for k, v in posts0.items():
    print(f"{k}: posts: {len(v)} words-rough: {len([ii for i in v for ii in i.split()])}")
# Out:
# cfact: posts: 34 words-rough: 22292
# ClimateChangeIsNatural: posts: 36 words-rough: 1349
# iloveco2: posts: 33 words-rough: 3256
# ClimateChangeLIES: posts: 37 words-rough: 1211
# australianclimatemadness: posts: 38 words-rough: 4085
# ClimateDepot: posts: 45 words-rough: 9188
# ccdispatch: posts: 38 words-rough: 694
# TheCO2Coalition: posts: 38 words-rough: 4894
# Global-Warming-Climate-Change-whatever-its-called-is-a-scam-241741379521: posts: 37 words-rough: 467
# Global-Climate-Scam-1392664020945768: posts: 38 words-rough: 619
# greenpeace.international: posts: 40 words-rough: 1954
# NASAClimateChange: posts: 38 words-rough: 2073
# bloomberggreen: posts: 38 words-rough: 1218
# acespace: posts: 26 words-rough: 1493
# ClimateChangeIsReal: posts: 39 words-rough: 6226
# climatereality: posts: 38 words-rough: 1230
# ClimateChangeNews: posts: 38 words-rough: 1712
# NatureClimateChange: posts: 38 words-rough: 1697
# ClimateChangeCauses: posts: 37 words-rough: 867
# GlobalwarmingEva: posts: 36 words-rough: 723

# %% [markdown]
# ### Load NLP engine

# %%
nlp = spacy.load("en_core_web_lg")

# %%
### Illustration
i = nlp('the a and')
for ii in i:
    print(ii, type(ii), ii.is_stop, str(ii) in nlp.Defaults.stop_words)
# Out:
# the <class 'spacy.tokens.token.Token'> False True
# a <class 'spacy.tokens.token.Token'> False True
# and <class 'spacy.tokens.token.Token'> False True

# %%
def lemmatize(posts):  
    lemmatized = {k: [token.lemma_ 
                       for token in nlp(". ".join(v)) 
                       if not str(token) in nlp.Defaults.stop_words and 
                       not token.is_punct and not token.is_space] 
                   for k, v in tqdm(posts.items())}
    return lemmatized

# %% [markdown]
# ### Remove stopwords, punctuation, spaces and lemmatize all the posts

# %%
lemmatized0 = lemmatize(posts0)
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=20.0), HTML(value='')))
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-75e3321e11fc> in <module>
# ----> 1 lemmatized0 = lemmatize(posts0)
#
# <ipython-input-15-71402026ed27> in lemmatize(posts)
#       4                        if not str(token) in nlp.Defaults.stop_words and
#       5                        not token.is_punct and not token.is_space]
# ----> 6                    for k, v in tqdm(posts.items())}
#       7     return lemmatized
#
# <ipython-input-15-71402026ed27> in <dictcomp>(.0)
#       4                        if not str(token) in nlp.Defaults.stop_words and
#       5                        not token.is_punct and not token.is_space]
# ----> 6                    for k, v in tqdm(posts.items())}
#       7     return lemmatized
#
# ~/anaconda3/envs/nlp/lib/python3.7/site-packages/spacy/language.py in __call__(self, text, disable)
#     344             if not hasattr(proc, '__call__'):
#     345                 raise ValueError(Errors.E003.format(component=type(proc), name=name))
# --> 346             doc = proc(doc)
#     347             if doc is None:
#     348                 raise ValueError(Errors.E005.format(name=name))
#
# nn_parser.pyx in spacy.syntax.nn_parser.Parser.__call__()
#
# nn_parser.pyx in spacy.syntax.nn_parser.Parser.parse_batch()
#
# nn_parser.pyx in spacy.syntax.nn_parser.Parser.get_batch_model()
#
# ~/anaconda3/envs/nlp/lib/python3.7/site-packages/thinc/api.py in begin_update(self, X, drop)
#      59         callbacks = []
#      60         for layer in self._layers:
# ---> 61             X, inc_layer_grad = layer.begin_update(X, drop=drop)
#      62             callbacks.append(inc_layer_grad)
#      63         def continue_update(gradient, sgd=None):
#
# ~/anaconda3/envs/nlp/lib/python3.7/site-packages/thinc/api.py in begin_update(seqs_in, drop)
#     278         lengths = layer.ops.asarray([len(seq) for seq in seqs_in])
#     279         X, bp_layer = layer.begin_update(layer.ops.flatten(seqs_in, pad=pad),
# --> 280                                          drop=drop)
#     281         if bp_layer is None:
#     282             return layer.ops.unflatten(X, lengths, pad=pad), None
#
# ~/anaconda3/envs/nlp/lib/python3.7/site-packages/thinc/api.py in begin_update(self, X, drop)
#      59         callbacks = []
#      60         for layer in self._layers:
# ---> 61             X, inc_layer_grad = layer.begin_update(X, drop=drop)
#      62             callbacks.append(inc_layer_grad)
#      63         def continue_update(gradient, sgd=None):
#
# ~/anaconda3/envs/nlp/lib/python3.7/site-packages/thinc/neural/_classes/resnet.py in begin_update(self, X, drop)
#      16
#      17     def begin_update(self, X, drop=0.):
# ---> 18         y, bp_y = self._layers[0].begin_update(X, drop=drop)
#      19         output = X+y
#      20         def residual_bwd(d_output, sgd=None):
#
# ~/anaconda3/envs/nlp/lib/python3.7/site-packages/thinc/api.py in begin_update(self, X, drop)
#      59         callbacks = []
#      60         for layer in self._layers:
# ---> 61             X, inc_layer_grad = layer.begin_update(X, drop=drop)
#      62             callbacks.append(inc_layer_grad)
#      63         def continue_update(gradient, sgd=None):
#
# ~/anaconda3/envs/nlp/lib/python3.7/site-packages/thinc/neural/_classes/layernorm.py in begin_update(self, X, drop)
#      49
#      50     def begin_update(self, X, drop=0.):
# ---> 51         X, backprop_child = self.child.begin_update(X, drop=0.)
#      52         N, mu, var = _get_moments(self.ops, X)
#      53
#
# ~/anaconda3/envs/nlp/lib/python3.7/site-packages/thinc/neural/_classes/maxout.py in begin_update(self, X__bi, drop)
#      67         W = self.W.reshape((self.nO * self.nP, self.nI))
#      68         drop *= self.drop_factor
# ---> 69         output__boc = self.ops.batch_dot(X__bi, W)
#      70         output__boc += self.b.reshape((self.nO*self.nP,))
#      71         output__boc = output__boc.reshape((output__boc.shape[0], self.nO, self.nP))
#
# ops.pyx in thinc.neural.ops.NumpyOps.batch_dot()
#
# <__array_function__ internals> in dot(*args, **kwargs)
#
# KeyboardInterrupt:

# %%
lemmatized1 = lemmatize(posts1)

# %%
lemmatized2_pos = lemmatize(posts2_pos)

# %%
lemmatized2_neg = lemmatize(posts2_neg)

# %%
lemmatized0
# Out:
# {'cfact': ['joe',
#   'biden',
#   'kamala',
#   'harris',
#   'aoc',
#   'democrat',
#   'party',
#   'us',
#   'environmentalist',
#   'commit',
#   'make',
#   'climate',
#   'change',
#   'green',
#   'new',
#   'deal',
#   'replacement',
#   'fossil',
#   'fuel',
#   'wind',
#   'solar',
#   'battery',
#   'biofuel',
#   'power',
#   'centerpiece',
#   'foreign',
#   'domestic',
#   'policy',
#   'share',
#   'fact',
#   'cfact.org',
#   '-PRON-',
#   'claim',
#   'transition',
#   'easy',
#   'affordable',
#   'ecological',
#   'sustainable',
#   'painless',
#   'that',
#   '’',
#   'ideology',
#   'fantasy',
#   'reality',
#   'wind',
#   'sunshine',
#   'certainly',
#   'clean',
#   'renewable',
#   'harness',
#   'power',
#   'america',
#   'the',
#   'gnd',
#   'hit',
#   'american',
#   'family',
#   'job',
#   'living',
#   'standard',
#   'environmental',
#   'quality',
#   'hard',
#   'western',
#   'state',
#   'feel',
#   'brunt',
#   'fossil',
#   'fuel',
#   'rent',
#   'royalty',
#   'job',
#   'tax',
#   'receipt',
#   'disappear',
#   'drilling',
#   'fracking',
#   'coal',
#   'mining',
#   'federal',
#   'land',
#   'close',
#   '-PRON-',
#   'open',
#   'space',
#   'scenic',
#   'vista',
#   'wildlife',
#   'habitat',
#   'wildlife',
#   'desecrate',
#   'wind',
#   'turbine',
#   'solar',
#   'panel',
#   'transmission',
#   'line',
#   'serve',
#   'distant',
#   'urban',
#   'voting',
#   'bloc',
#   'dictate',
#   'energy',
#   'land',
#   'use',
#   'decision',
#   'far',
#   'city',
#   'line',
#   'coal',
#   'oil',
#   'natural',
#   'gas',
#   'petroleum',
#   'liquid',
#   'provide',
#   '80',
#   'us',
#   'energy',
#   'in',
#   '2018',
#   'generate',
#   '2.7',
#   'billion',
#   'megawatt',
#   'hour',
#   'mwh',
#   'electricity',
#   'replace',
#   'encompass',
#   'green',
#   'new',
#   'deal',
#   'cost',
#   'ten',
#   'trillion',
#   'dollar',
#   'another',
#   '2.7',
#   'billion',
#   'mwh',
#   'worth',
#   'natural',
#   'gas',
#   'power',
#   'factory',
#   'emergency',
#   'power',
#   'system',
#   'furnace',
#   'oven',
#   'stove',
#   'hot',
#   'water',
#   'heater',
#   'restaurant',
#   'home',
#   'building',
#   'car',
#   'truck',
#   'bus',
#   'semi',
#   'trailer',
#   'tractor',
#   'vehicle',
#   'consume',
#   'equivalent',
#   '2',
#   'billion',
#   'mwh',
#   'altogether',
#   '’',
#   '7.4',
#   'billion',
#   'megawatt',
#   'hour',
#   'year',
#   'gnd',
#   'replace',
#   'on',
#   'would',
#   'need',
#   '150',
#   'million',
#   'mwh',
#   'wind',
#   'solar',
#   'generating',
#   'capacity',
#   'charge',
#   'battery',
#   'maintain',
#   'week',
#   'nationwide',
#   'backup',
#   'power',
#   'avoid',
#   'blackout',
#   'the',
#   'try',
#   'would',
#   'turbine',
#   'panel',
#   'low',
#   'quality',
#   'wind',
#   'solar',
#   'site',
#   'would',
#   'generate',
#   'electricity',
#   '15',
#   '20',
#   'year',
#   '80',
#   '85',
#   'nameplate',
#   'capacity',
#   'of',
#   'course',
#   'replace',
#   'fossil',
#   'fuel',
#   'energy',
#   'nuclear',
#   'power',
#   'but',
#   'radical',
#   'green',
#   'inside',
#   'outside',
#   'soon',
#   'biden',
#   'administration',
#   'detest',
#   'oppose',
#   'nuclear',
#   'fossil',
#   'fuel',
#   'that',
#   'mean',
#   'transformation',
#   'electric',
#   'nation',
#   'require',
#   'million',
#   'onshore',
#   'wind',
#   'turbine',
#   'thousand',
#   'offshore',
#   'turbine',
#   'billion',
#   'solar',
#   'panel',
#   'million',
#   'vehicle',
#   'battery',
#   'module',
#   'billion',
#   'backup',
#   'energy',
#   'storage',
#   'battery',
#   'module',
#   'thousand',
#   'mile',
#   'new',
#   'transmission',
#   'line',
#   'million',
#   'charge',
#   'station',
#   'ten',
#   'billion',
#   'ton',
#   'concrete',
#   'steel',
#   'copper',
#   'plastic',
#   'cobalt',
#   'rare',
#   'earth',
#   'element',
#   'countless',
#   'material',
#   'dig',
#   'hundred',
#   'billion',
#   'ton',
#   'overburden',
#   'ore',
#   'if',
#   'united',
#   'states',
#   'world',
#   'summon',
#   'process',
#   'smell',
#   'metal',
#   'mineral',
#   'manufacture',
#   'transport',
#   'install',
#   'turbine',
#   'panel',
#   'battery',
#   'transmission',
#   'line',
#   'gnd',
#   'require',
#   'great',
#   'expansion',
#   'mining',
#   'manufacturing',
#   'human',
#   'history',
#   'but',
#   'radical',
#   'green',
#   'inside',
#   'outside',
#   'biden',
#   'administration',
#   'detest',
#   'oppose',
#   'us',
#   'mining',
#   'manufacture',
#   'despise',
#   'fossil',
#   'fuel',
#   'that',
#   'mean',
#   'overseas',
#   'essential',
#   'metal',
#   'mineral',
#   'primarily',
#   'china',
#   'russia',
#   'boundary',
#   'control',
#   'african',
#   'asian',
#   'latin',
#   'american',
#   'nation',
#   '-PRON-',
#   'reservation',
#   'hesitation',
#   'dig',
#   'process',
#   'regard',
#   'child',
#   'slave',
#   'force',
#   'labor',
#   'workplace',
#   'safety',
#   'air',
#   'water',
#   'pollution',
#   'mine',
#   'land',
#   'reclamation',
#   'standard',
#   'insist',
#   'america',
#   'and',
#   '’',
#   'highly',
#   'unlikely',
#   'team',
#   'biden',
#   'demand',
#   'country',
#   'implement',
#   'standard',
#   'refuse',
#   'import',
#   'metal',
#   'mineral',
#   'finish',
#   'green',
#   'technology',
#   'china',
#   'russia',
#   'foreign',
#   'subsidiary',
#   'abide',
#   'rule',
#   'regulation',
#   'the',
#   'entire',
#   'gnd',
#   'collapse',
#   'unethical',
#   'raw',
#   'material',
#   'moreover',
#   'nearly',
#   'mining',
#   'processing',
#   'manufacturing',
#   'require',
#   'gasoline',
#   'diesel',
#   'natural',
#   'gas',
#   'coal',
#   'foreign',
#   'country',
#   'operation',
#   'conduct',
#   'wind',
#   'solar',
#   'battery',
#   'power',
#   'the',
#   'fossil',
#   'fuel',
#   'use',
#   'emission',
#   'place',
#   'outside',
#   'united',
#   'states',
#   'away',
#   'indeed',
#   'likely',
#   'double',
#   'triple',
#   'the',
#   'carbon',
#   'dioxide',
#   'emission',
#   'increase',
#   'global',
#   'atmospheric',
#   'level',
#   'team',
#   'biden',
#   'insist',
#   'worsen',
#   'climate',
#   'chaos',
#   'extreme',
#   'weather',
#   'in',
#   'fact',
#   'wind',
#   'solar',
#   'battery',
#   'mining',
#   'processing',
#   'manufacturing',
#   'place',
#   'overseas',
#   'nonexistent',
#   'workplace',
#   'safety',
#   'fair',
#   'wage',
#   'child',
#   'labor',
#   'environmental',
#   'law',
#   'some',
#   '40,000',
#   'congolese',
#   'child',
#   'labor',
#   'alongside',
#   'parent',
#   'couple',
#   'dollar',
#   'day',
#   'expose',
#   'constantly',
#   'toxic',
#   'radioactive',
#   'mud',
#   'dust',
#   'water',
#   'air',
#   'meet',
#   'today',
#   '’s',
#   'cobalt',
#   'need',
#   'imagine',
#   'gnd',
#   'toll',
#   'replace',
#   'oil',
#   'gas',
#   'petrochemical',
#   'pharmaceutical',
#   'plastic',
#   'require',
#   'import',
#   'feed',
#   'stock',
#   'plant',
#   'million',
#   'acre',
#   'canola',
#   'soybean',
#   'biofuel',
#   'crop',
#   'the',
#   'water',
#   'fertilizer',
#   'pesticide',
#   'tractor',
#   'harvester',
#   'processing',
#   'transportation',
#   'requirement',
#   'astronomical',
#   'all',
#   'work',
#   'industrial',
#   'facility',
#   'impact',
#   'hundred',
#   'million',
#   'acre',
#   'scenic',
#   'area',
#   'food',
#   'crop',
#   'land',
#   'wildlife',
#   'habitat',
#   'raptor',
#   'bird',
#   'bat',
#   'forest',
#   'grassland',
#   'desert',
#   'dweller',
#   'suffer',
#   'substantial',
#   'loss',
#   'drive',
#   'extinction',
#   'most',
#   'impact',
#   'occur',
#   'midwestern',
#   'western',
#   'america',
#   'far',
#   'voting',
#   'center',
#   'suspicious',
#   'voting',
#   'pattern',
#   'team',
#   'biden',
#   'office',
#   'but',
#   'sight',
#   'mind',
#   '’s',
#   'backyard',
#   'the',
#   'gnd',
#   'mean',
#   'rip',
#   'perfectly',
#   'good',
#   'natural',
#   'gas',
#   'appliance',
#   'replace',
#   'electric',
#   'model',
#   'instal',
#   'rapid',
#   'charge',
#   'system',
#   'vehicle',
#   'upgrade',
#   'household',
#   'neighborhood',
#   'national',
#   'electrical',
#   'system',
#   'handle',
#   'extra',
#   'load',
#   'cost',
#   'trillion',
#   'dollar',
#   'families',
#   'factory',
#   'hospital',
#   'school',
#   'business',
#   'accustom',
#   'pay',
#   '7',
#   '11¢',
#   'kilowatt',
#   'hour',
#   'electricity',
#   'pay',
#   '14',
#   '22¢',
#   'kwh',
#   'green',
#   'us',
#   'state',
#   '35¢',
#   'family',
#   'pay',
#   'germany',
#   'once',
#   'use',
#   'arbitrary',
#   'maximum',
#   'baseline',
#   'electricity',
#   'month',
#   'pay',
#   'close',
#   '45¢',
#   'kwh',
#   'family',
#   'california',
#   'how',
#   'company',
#   'survive',
#   'job',
#   'disappear',
#   'family',
#   'join',
#   'rank',
#   'choose',
#   'heating',
#   'eat',
#   '’s',
#   'guess',
#   'gnd',
#   'technology',
#   'nearly',
#   '100',
#   'dependent',
#   'metal',
#   'mineral',
#   'china',
#   'russia',
#   'ukraine',
#   'chinese',
#   'company',
#   'africa',
#   'latin',
#   'america',
#   'email',
#   'hunter',
#   'biden',
#   '’s',
#   'laptop',
#   'underscore',
#   'concern',
#   'america',
#   '’s',
#   'foreign',
#   'defense',
#   'domestic',
#   'policy',
#   'hold',
#   'hostage',
#   'certain',
#   'connect',
#   'politician',
#   'family',
#   'wind',
#   'solar',
#   'battery',
#   'biofuel',
#   'company',
#   'rich',
#   'all',
#   'issue',
#   'require',
#   'open',
#   'robust',
#   'debate',
#   'school',
#   'university',
#   'news',
#   'social',
#   'medium',
#   'outlet',
#   'corporate',
#   'political',
#   'leader',
#   'antifa',
#   'thug',
#   'arsonist',
#   'continue',
#   'censor',
#   'cancel',
#   'that',
#   'censorship',
#   'silencing',
#   'end',
#   'vote',
#   'action',
#   'take',
#   'green',
#   'new',
#   'deal',
#   'unfortunately',
#   'opposite',
#   'happen',
#   'big',
#   'media',
#   'big',
#   'tech',
#   'conspire',
#   'democrats',
#   'greens',
#   'authoritarian',
#   'element',
#   'shut',
#   'discussion',
#   'support',
#   'agenda',
#   'other',
#   'move',
#   'persecute',
#   'prosecute',
#   'president',
#   'trump',
#   'associate',
#   'administration',
#   'policy',
#   'as',
#   'anger',
#   'frustration',
#   'build',
#   'increasingly',
#   'disenfranchised',
#   'america',
#   'world',
#   'head',
#   'frightening',
#   'future',
#   'cfact.org',
#   'green',
#   'new',
#   'deal',
#   'ideology',
#   'fantasy',
#   'reality',
#   '-PRON-',
#   'content',
#   'facebook',
#   'twitter',
#   'google',
#   'amazon',
#   'effectively',
#   'monopoly',
#   'niche',
#   'should',
#   'big',
#   'tech',
#   'power',
#   'silence',
#   'question',
#   'leave',
#   'share',
#   'fact',
#   'cfact.org',
#   'the',
#   'large',
#   'social',
#   'medium',
#   'search',
#   'company',
#   'a.k.a',
#   'big',
#   'tech',
#   'long',
#   'closet',
#   'come',
#   'censorship',
#   'cfact',
#   'document',
#   '-PRON-',
#   'write',
#   '19',
#   'month',
#   'ago',
#   'predate',
#   'analysis',
#   'big',
#   'tech',
#   'abandon',
#   'masquerade',
#   'standard',
#   'objectivity',
#   'censor',
#   'dislike',
#   'disagree',
#   'in',
#   'fact',
#   'blare',
#   'increase',
#   'backing',
#   'politician',
#   'swear',
#   'oath',
#   'constitution',
#   'document',
#   'guarantee',
#   'free',
#   'speech',
#   'inalienable',
#   'right',
#   'the',
#   'name',
#   'big',
#   'tech',
#   'mogul',
#   'increasingly',
#   'familiar',
#   'include',
#   'jack',
#   'dorsey',
#   'twitter',
#   'mark',
#   'zuckerberg',
#   'facebook',
#   'own',
#   'instagram',
#   'jeff',
#   'bezos',
#   'amazon',
#   'sundar',
#   'pichai',
#   'google',
#   'own',
#   'youtube',
#   'none',
#   'individual',
#   'reach',
#   'comparative',
#   'wealth',
#   '19th',
#   'century',
#   'robber',
#   'baron',
#   'john',
#   'd.',
#   'rockefeller',
#   'oil',
#   'andrew',
#   'carnegie',
#   'steel',
#   'j.p.',
#   'morgan',
#   'finance',
#   'however',
#   '21st',
#   'century',
#   'robber',
#   'baron',
#   'powerful',
#   'the',
#   '19th',
#   'century',
#   'economic',
#   'titan',
#   'control',
#   'industry',
#   'crushed',
#   'competition',
#   'business',
#   '-PRON-',
#   'disproportionate',
#   'control',
#   'economy',
#   'people',
#   '’s',
#   'livelihood',
#   'america',
#   '’s',
#   'standard',
#   'live',
#   'improve',
#   'industrial',
#   'age',
#   'thank',
#   'president',
#   'theodore',
#   'roosevelt',
#   'courageous',
#   'politician',
#   'judge',
#   'early',
#   '20th',
#   'century',
#   'monopoly',
#   'declare',
#   'illegal',
#   'break',
#   'the',
#   '21st',
#   'century',
#   'tech',
#   'giant',
#   'similarly',
#   'crush',
#   'competition',
#   'late',
#   'flagrant',
#   'example',
#   'information',
#   'platform',
#   'parler',
#   'more',
#   'insidious',
#   '19th',
#   'century',
#   'monopoly',
#   'big',
#   'tech',
#   '’s',
#   'control',
#   'information',
#   'control',
#   'public',
#   'know',
#   'ultimate',
#   'power',
#   'dictatorship',
#   'understand',
#   'influence',
#   'behavior',
#   'populace',
#   'stifle',
#   'opposition',
#   'increase',
#   'political',
#   'economic',
#   'power',
#   'just',
#   'big',
#   'tech',
#   'consist',
#   'private',
#   'company',
#   'government',
#   'abridgment',
#   'legal',
#   'acceptable',
#   'as',
#   '19th',
#   'century',
#   'predecessors’',
#   'threat',
#   'economic',
#   'freedom',
#   'power',
#   'control',
#   'mass',
#   'today',
#   '’s',
#   'monopolistic',
#   'threat',
#   'constitutional',
#   'freedom',
#   'examples',
#   'information',
#   'control',
#   'abound',
#   'last',
#   'spring',
#   'president',
#   'trump',
#   'suggest',
#   'hydroxychloroquine',
#   'help',
#   'treat',
#   'coronavirus',
#   'view',
#   'hold',
#   'countless',
#   'physician',
#   'youtube',
#   'facebook',
#   'censor',
#   'people',
#   ...],
#  'ClimateChangeIsNatural': ['the',
#   'fake',
#   'news',
#   'medium',
#   'bust',
#   'peddle',
#   'lie',
#   'have',
#   'see',
#   'dhs',
#   'refute',
#   'fbi',
#   "'s",
#   'fearmongering',
#   'online',
#   'chatter',
#   'note',
#   'fact',
#   'credible',
#   'threat',
#   'federal',
#   'prosecutor',
#   'force',
#   'refute',
#   'appear',
#   'lie',
#   'strong',
#   'evidence',
#   'assassination',
#   'squad',
#   'the',
#   'capitol',
#   'arizona',
#   'state',
#   'prosecutor',
#   'have',
#   'mainstream',
#   'medium',
#   "'s",
#   'news',
#   'cycle',
#   'today',
#   'great',
#   'job',
#   'ratchet',
#   'fear',
#   '11',
#   'zerohedge.com',
#   'us',
#   'official',
#   'refute',
#   'arizona',
#   'prosecutors',
#   'claim',
#   'about',
#   'rioters',
#   'plan',
#   'to',
#   'capture',
#   'assassinate',
#   'politicians',
#   'cbn',
#   'news',
#   'january',
#   '8',
#   '5:30',
#   'pm',
#   'biden',
#   'harris',
#   'white',
#   'house',
#   'democrat',
#   'control',
#   'congress',
#   'ready',
#   'great',
#   'reset',
#   'what',
#   'mean',
#   'the',
#   'left',
#   'responsible',
#   'turning',
#   'point',
#   'usa',
#   'post',
#   'video',
#   'playlist',
#   'benny',
#   'on',
#   'the',
#   'block',
#   '20',
#   'hr',
#   'here',
#   'washington',
#   'national',
#   'guard',
#   'deploy',
#   'massive',
#   'gate',
#   'surround',
#   'federal',
#   'building',
#   'this',
#   'city',
#   'look',
#   'like',
#   'war',
#   'zone',
#   'if',
#   'live',
#   'deal',
#   'all',
#   'summer',
#   'long',
#   'the',
#   'culture',
#   'political',
#   'violence',
#   'country',
#   'systemic',
#   'need',
#   'to',
#   'stop',
#   'where',
#   'come',
#   'who',
#   'normalize',
#   'why',
#   'people',
#   'suddenly',
#   'selectively',
#   'outraged',
#   'and',
#   'stop',
#   'have',
#   'national',
#   'treasure',
#   'national',
#   'consciousness',
#   'look',
#   'like',
#   'foreign',
#   'war',
#   'zone',
#   'in',
#   'week',
#   '’s',
#   'episode',
#   'benny',
#   'on',
#   'the',
#   'block',
#   'benny',
#   'johnson',
#   'explore',
#   'recent',
#   'history',
#   'normalization',
#   'political',
#   'violence',
#   'country',
#   'you',
#   'must',
#   'watch!.',
#   'this',
#   'political',
#   'persecution',
#   'this',
#   'evil',
#   'be',
#   'kind',
#   'society',
#   'want',
#   'live',
#   'tucker',
#   'carlson',
#   'tonight',
#   'yesterday',
#   '1:57',
#   'am',
#   'musician',
#   'ariel',
#   'pink',
#   'not',
#   'capitol',
#   'hill',
#   'riot',
#   'but',
#   'cancel',
#   'culture',
#   'rage',
#   'mob',
#   'come',
#   'and',
#   'prophecy',
#   'foretell',
#   'warm',
#   'winter',
#   '’cheap',
#   'renewable',
#   'push',
#   'demand',
#   'fossil',
#   'fuel',
#   'i.e',
#   'store',
#   'solar',
#   'energy',
#   'bloomberg.com',
#   'cold',
#   'snap',
#   'prompt',
#   'fuel',
#   'oil',
#   'frenzy',
#   'power',
#   'starved',
#   'asia',
#   'the',
#   'usa',
#   'trouble',
#   'what',
#   'go',
#   'democrat',
#   'long',
#   'authoritarian',
#   'crazy',
#   'youtube.com',
#   'tucker',
#   'carlson',
#   'tonight',
#   '1/15/21',
#   'full',
#   '|',
#   'fox',
#   'break',
#   'trump',
#   'news',
#   'january',
#   '15',
#   '21',
#   'let',
#   '-PRON-',
#   'boycott',
#   'bully',
#   'share',
#   'it!.',
#   'left',
#   'wing',
#   'activist',
#   'criticise',
#   'us',
#   'medium',
#   'outlet',
#   'politico',
#   '’s',
#   'decision',
#   'invite',
#   'conservative',
#   'podcaster',
#   'ben',
#   'shapiro',
#   'edit',
#   'daily',
#   'newspaper',
#   'playbook’',
#   'skynews.com.au',
#   'left',
#   'wing',
#   'snowflake',
#   'object',
#   'conservative',
#   'ben',
#   'shapiro',
#   'guest',
#   'editing',
#   'politico',
#   'newsletter',
#   '|',
#   'sky',
#   'news',
#   'australia',
#   'these',
#   'student',
#   'go',
#   'insane',
#   'clown',
#   'fox',
#   'guy',
#   'think',
#   'ok',
#   'youtube.com',
#   'harvard',
#   'student',
#   'push',
#   'strip',
#   'conservative',
#   'diploma',
#   'let',
#   '-PRON-',
#   'hope',
#   'joe',
#   'biden',
#   '’s',
#   'minimum',
#   'wage',
#   'fantasy',
#   'law',
#   'worker',
#   'pay',
#   'price',
#   'economic',
#   'naiveté',
#   'fee.org',
#   'company',
#   'be',
#   'prepare',
#   'cut',
#   'jobs',
#   'automate',
#   'biden',
#   'get',
#   '$',
#   '15',
#   'minimum',
#   'wage',
#   'hike',
#   'reporting',
#   'show',
#   '|',
#   'brad',
#   'polumbo',
#   'more',
#   'come',
#   'foxnews.com',
#   'twitter',
#   'whistleblower',
#   'leak',
#   'video',
#   'dorsey',
#   'tell',
#   'staff',
#   'action',
#   'big',
#   'trump',
#   'ban',
#   'snowfall',
#   'hokkaido',
#   'northern',
#   'japan',
#   'the',
#   'cancel',
#   'culture',
#   'like',
#   'mao',
#   "'s",
#   'cultural',
#   'revolution',
#   '-PRON-',
#   'constantly',
#   'need',
#   'feed',
#   'new',
#   'blood',
#   'new',
#   'victim',
#   'censor',
#   'shame',
#   'cancel',
#   'eventually',
#   'everybodys',
#   'turn',
#   'meat',
#   'grinder',
#   'revolution',
#   'eat',
#   'child',
#   'when',
#   'come',
#   'facebook',
#   'broken',
#   'platform',
#   'completely',
#   'useless',
#   'get',
#   'wake',
#   'broke',
#   'go',
#   'way',
#   'myspace',
#   'soon',
#   '🤷',
#   '\u200d',
#   '♂',
#   '️',
#   'youtube.com',
#   'facebook',
#   'have',
#   'restrict',
#   '-PRON-',
#   'page',
#   'effectively',
#   'shut',
#   'down',
#   'the',
#   'purge',
#   'be',
#   'real',
#   'and',
#   'will',
#   'get',
#   'worse',
#   'this',
#   'democrat',
#   'congressman',
#   'harold',
#   'ford',
#   'jr.',
#   'be',
#   'picture',
#   'mao',
#   'wall',
#   'why',
#   'yes',
#   'any',
#   'indication',
#   'leaning',
#   'certain',
#   'dems',
#   'poppcorn',
#   'time',
#   '🍿',
#   '😎',
#   '🥤',
#   'zerohedge.com',
#   'trump',
#   'declassifies',
#   'foot',
#   'high',
#   'stack',
#   'of',
#   'russiagate',
#   'obamagate',
#   'documents',
#   'set',
#   'for',
#   'release',
#   'within',
#   'days',
#   'really',
#   'good',
#   'inteview',
#   'must',
#   'watch',
#   'youtube.com',
#   '-PRON-',
#   'be',
#   'live',
#   'gigantic',
#   'lie’—dennis',
#   'prager',
#   'talks',
#   'free',
#   'speech',
#   '|',
#   'american',
#   'thought',
#   'leader',
#   'delete',
#   'twitter',
#   'account',
#   'breitbart.com',
#   'project',
#   'veritas',
#   'video',
#   'show',
#   'twitter',
#   'ceo',
#   'jack',
#   'dorsey',
#   'say',
#   'censorship',
#   'be',
#   'not',
#   'go',
#   'away',
#   'anytime',
#   'soon',
#   '-PRON-',
#   'finish',
#   'vote',
#   'trump',
#   'breitbart.com',
#   'wyoming',
#   'gop',
#   'liz',
#   'cheney',
#   "'s",
#   'impeachment',
#   'vote',
#   'spark',
#   'unprecedented',
#   'outcry',
#   '🤣',
#   'critic',
#   'silicon',
#   'valley',
#   'censorship',
#   'year',
#   'hear',
#   'refrain',
#   'tech',
#   'platform',
#   'like',
#   'facebook',
#   'google',
#   'twitter',
#   'private',
#   'corporation',
#   'host',
#   'ban',
#   'want',
#   'if',
#   'not',
#   'like',
#   'solution',
#   'complain',
#   'regulate',
#   'instead',
#   'create',
#   'social',
#   'medium',
#   'platform',
#   'operate',
#   'way',
#   'think',
#   'the',
#   'founder',
#   'parler',
#   'hear',
#   'suggestion',
#   'try',
#   'in',
#   'august',
#   '2018',
#   'create',
#   'social',
#   'medium',
#   'platform',
#   'similar',
#   'twitter',
#   'promise',
#   'far',
#   'great',
#   'privacy',
#   'protection',
#   'include',
#   'refusal',
#   'aggregate',
#   'user',
#   'datum',
#   'order',
#   'monetize',
#   'advertiser',
#   'algorithmically',
#   'evaluate',
#   'interest',
#   'order',
#   'promote',
#   'content',
#   'product',
#   '-PRON-',
#   'promise',
#   'far',
#   'great',
#   'free',
#   'speech',
#   'right',
#   'reject',
#   'increasingly',
#   'repressive',
#   'content',
#   'policing',
#   'silicon',
#   'valley',
#   'giant',
#   'ronpaulinstitute.org',
#   'how',
#   'silicon',
#   'valley',
#   'show',
#   'monopolistic',
#   'force',
#   'destroyed',
#   'parler',
#   'nytimes',
#   'falsely',
#   'link',
#   'capitol',
#   'riot',
#   'and',
#   'climate',
#   'disinformation',
#   'do',
#   'think',
#   'nyt',
#   'credible',
#   'newspaper',
#   '🤦',
#   '\u200d',
#   '♂',
#   '️',
#   '🤡',
#   'climatechangedispatch.com',
#   'nytimes',
#   'falsely',
#   'link',
#   'capitol',
#   'riot',
#   'and',
#   'climate',
#   'disinformation’',
#   '😂',
#   '😂',
#   '😂',
#   'democrat',
#   'clown',
#   'foxnews.com',
#   'journalists',
#   'falsely',
#   'accuse',
#   'louie',
#   'gohmert',
#   'call',
#   'uprising',
#   'quote',
#   'pelosi',
#   'craig',
#   'kelly',
#   'january',
#   '14',
#   '3:52',
#   'am',
#   'inigo',
#   'wins',
#   'again',
#   'during',
#   'great',
#   'heatwave',
#   'january',
#   '1939',
#   'australia',
#   '’s',
#   'legendary',
#   'long',
#   'term',
#   'weather',
#   'forecaster',
#   'inigo',
#   'jones',
#   'report',
#   'the',
#   'singleton',
#   'argus',
#   'this',
#   'widespread',
#   'heat',
#   'wave',
#   'affect',
#   'state',
#   'simultaneously',
#   'forerunner',
#   'drought',
#   'precursor',
#   'rain',
#   '-PRON-',
#   'cyclical',
#   'come',
#   'round',
#   '35',
#   'year',
#   'interval',
#   'https://trove.nla.gov.au/newspaper/article/81944110?searchterm=heatwave',
#   'in',
#   'contrast',
#   'mr',
#   'flannery',
#   'claim',
#   '’so',
#   'rain',
#   'fall',
#   'will',
#   'not',
#   'fill',
#   'dam',
#   'river',
#   'warragamba',
#   'dam',
#   'fill',
#   'https://www.abc.net.au/local/archives/landline/content/2006/s1844398.htm',
#   'https://www.smh.com.au/national/running-out-of-water-and-time-20050425-gdl6xe.html',
#   'and',
#   'remember',
#   'early',
#   '2020',
#   'extreme',
#   'heat',
#   'experts’',
#   'warn',
#   'drying',
#   'continent',
#   'place',
#   '2020',
#   'turn',
#   'wet',
#   'record',
#   'inigo',
#   'jones',
#   'man',
#   'true',
#   'science',
#   'prove',
#   'correct',
#   'https://www.smh.com.au/environment/weather/2020-was-sydney-s-wettest-year-in-two-decades-and-there-is-more-to-come-20210101-p56r8t.html',
#   'double',
#   'standard',
#   '🤷',
#   '\u200d',
#   '♂',
#   '️.',
#   'come',
#   'soon',
#   '-PRON-',
#   'need',
#   'co2',
#   'climatechangedispatch.com',
#   'why',
#   'carbon',
#   'dioxide',
#   'be',
#   'natural',
#   'and',
#   'essential',
#   'nancy',
#   'pelosi',
#   "'s",
#   'tweet',
#   'suggest',
#   'russia',
#   'donald',
#   'trump',
#   "'s",
#   '2016',
#   'election',
#   'win',
#   'remain',
#   'untouched',
#   'lead',
#   'call',
#   'consistency',
#   'twitter',
#   'continue',
#   'hit',
#   'doubt',
#   'joe',
#   'biden',
#   "'s",
#   'victory',
#   'skynews.com.au',
#   'twitter',
#   'red',
#   'face',
#   'pelosi',
#   'tweet',
#   'resurface',
#   'declare',
#   'clinton',
#   'trump',
#   'election',
#   'hijack',
#   '|',
#   'sky',
#   'news',
#   'australia',
#   'twitter',
#   'cop',
#   'online',
#   'backlash',
#   'ironically',
#   'post',
#   'tweet',
#   'censor',
#   'speech',
#   'basic',
#   'human',
#   'right',
#   'election',
#   'day',
#   'ban',
#   'president',
#   'trump',
#   '’s',
#   'account',
#   'the',
#   'tech',
#   'giant',
#   'post',
#   'tweet',
#   'public',
#   'policy',
#   'account',
#   'say',
#   'ahead',
#   'ugandan',
#   'election',
#   'be',
#   'hear',
#   'report',
#   'internet',
#   'service',
#   'provider',
#   'order',
#   'block',
#   'social',
#   'medium',
#   'messaging',
#   'app',
#   '-PRON-',
#   'strongly',
#   'condemn',
#   'internet',
#   'shutdowns-',
#   'hugely',
#   'harmful',
#   'violate',
#   'basic',
#   'human',
#   'right',
#   'principle',
#   'openinternet',
#   'skynews.com.au',
#   'twitter',
#   'hypocritically',
#   'campaign',
#   'free',
#   'speech',
#   'ban',
#   'donald',
#   'trump',
#   '|',
#   'sky',
#   'news',
#   'australia',
#   '-PRON-',
#   'get',
#   'fire',
#   'dailywire.com',
#   'pbs',
#   'employee',
#   'out',
#   'after',
#   'comment',
#   'on',
#   're',
#   'education',
#   'camps’',
#   'for',
#   'trump',
#   'supporters',
#   '-PRON-',
#   'want',
#   'real',
#   'tower',
#   'babel',
#   '🤦',
#   '\u200d',
#   '♂',
#   '️',
#   'politico.eu',
#   'eu',
#   'stop',
#   'speak',
#   'broken',
#   'english’',
#   'brexit',
#   'say',
#   'french',
#   'minister',
#   'destroy',
#   'free',
#   'market',
#   'undo',
#   'million',
#   'people',
#   'die',
#   'achieve',
#   'fee.org',
#   'college',
#   'student',
#   '-PRON-',
#   'generation',
#   'be',
#   'blind',
#   'prosperity',
#   'around',
#   'us',
#   '|',
#   'alyssa',
#   'ahlgren',
#   'shameful',
#   'drroyspencer.com',
#   'at',
#   'white',
#   'house',
#   'purge',
#   'skeptics',
#   'have',
#   'start',
#   'roy',
#   'spencer',
#   'phd',
#   'roy',
#   'w.',
#   'spencer',
#   'january',
#   '12',
#   '10:17',
#   'pm',
#   'at',
#   'white',
#   'house',
#   'climate',
#   'skeptic',
#   'dr.',
#   'david',
#   'legates',
#   'fire',
#   'head',
#   'ostp',
#   'roy',
#   'w.',
#   'spencer',
#   'january',
#   '12',
#   '10:17',
#   'pm',
#   'at',
#   'white',
#   'house',
#   'climate',
#   'skeptic',
#   'dr.',
#   'david',
#   'legates',
#   'fire',
#   'head',
#   'ostp',
#   'an',
#   'impressive',
#   'crowd',
#   'gather',
#   'hear',
#   'trump',
#   'speak',
#   'border',
#   'city',
#   'alamo',
#   'texas',
#   'skynews.com.au',
#   'impressive',
#   'crowd',
#   'gather',
#   'trump',
#   'speech',
#   'texas',
#   '|',
#   'sky',
#   'news',
#   'australia'],
#  'iloveco2': ['lord',
#   'patience',
#   'deal',
#   'thing',
#   '-PRON-',
#   'change',
#   'right',
#   'https://link.theepochtimes.com/mkt_app/paris-climate-treaty-puts-america-last_3591635.html',
#   'theepochtimes.com',
#   'paris',
#   'climate',
#   'treaty',
#   'put',
#   'america',
#   'last',
#   'whatev',
#   'drama',
#   'day',
#   'photosynthesis',
#   'continue',
#   'magic',
#   'proud',
#   'to',
#   'be',
#   'canadian',
#   'december',
#   '21',
#   '2020',
#   '6:00',
#   'am',
#   'ouch',
#   'have',
#   'courage',
#   'mr',
#   'president',
#   'at',
#   'iloveco2',
#   'try',
#   'political',
#   'opinion',
#   'focus',
#   'co2',
#   'climate',
#   'scam',
#   'fight',
#   'free',
#   'speech',
#   'attempt',
#   'feedom',
#   'hat',
#   'democrat',
#   'steal',
#   'usa',
#   'election',
#   'force',
#   'leave',
#   'comfort',
#   'zone',
#   'because',
#   'usa',
#   'supreme',
#   'court',
#   'abdicate',
#   'responsibility',
#   'cowardice',
#   'look',
#   'obvious',
#   'electoral',
#   'fraud',
#   'ask',
#   'president',
#   'trump',
#   'use',
#   'lawfully',
#   'available',
#   'right',
#   'invoke',
#   '14th',
#   'amendment',
#   'usa',
#   'constitution',
#   'insurrection',
#   'act',
#   'use',
#   'military',
#   'impose',
#   'martial',
#   'law',
#   'dispute',
#   'swing',
#   'state',
#   'recount',
#   'legal',
#   'vote',
#   'all',
#   'member',
#   'usa',
#   'military',
#   'oath',
#   'protect',
#   'usa',
#   'threat',
#   'foreign',
#   'domestic',
#   'president',
#   'courage',
#   'invoke',
#   '14th',
#   'duty',
#   'job',
#   'save',
#   'communist',
#   'coup',
#   'happen',
#   '-PRON-',
#   '’',
#   'strange',
#   'position',
#   'freedom',
#   'love',
#   'person',
#   'martial',
#   'law',
#   'but',
#   'reality',
#   'situation',
#   'demand',
#   '’',
#   'steal',
#   'stop',
#   'hope',
#   'climate',
#   'sanity',
#   'lot',
#   'freedom',
#   'grant',
#   'go',
#   'future',
#   'election',
#   'able',
#   'change',
#   '-PRON-',
#   'will',
#   'not',
#   'pretty',
#   'have',
#   'courage',
#   'mr',
#   'president',
#   '-PRON-',
#   'not',
#   'hate',
#   'co2',
#   'love',
#   'planet',
#   'cole',
#   'rob',
#   'boutilier',
#   'december',
#   '16',
#   '2020',
#   '4:35',
#   'pm',
#   'this',
#   'be',
#   'head',
#   'friend',
#   'john',
#   'rofe',
#   'write',
#   'ongoing',
#   'greek',
#   'tragedy',
#   'new',
#   'zealand',
#   '’s',
#   'fanaticism',
#   'try',
#   'save',
#   'planet',
#   'natural',
#   'cycle',
#   'trace',
#   'gas',
#   'co2',
#   'unlike',
#   'greece',
#   'new',
#   'zealand',
#   'not',
#   'eu',
#   'bail',
#   '’',
#   'economy',
#   'not',
#   'abuse',
#   'https://thebfd.co.nz/2020/12/13/our-intelligence-is-insulted-by-the-declaration-of-a-climate-emergency-by-the-prime-minister/',
#   'thebfd.co.nz',
#   'the',
#   'bfd',
#   '|',
#   '-PRON-',
#   'intelligence',
#   'be',
#   'insult',
#   'declaration',
#   'climate',
#   'emergency',
#   'prime',
#   'minister',
#   'no',
#   'fun',
#   'return',
#   'copious',
#   'quantity',
#   'carbon',
#   'dioxide',
#   'atmosphere',
#   'chuck',
#   'yeager',
#   '-PRON-',
#   'celebrate',
#   'amazing',
#   'life',
#   'aviation',
#   'legend',
#   'new',
#   'zealand',
#   'declare',
#   'stupidity',
#   'emergency',
#   'https://www.newstalkzb.co.nz/on-air/heather-du-plessis-allan-drive/video/heather-du-plessis-allan-climate-change-is-not-the-biggest-emergency-nz-is-facing/?fbclid=iwar2o2njvq6mukbfxae7ppta6tuv9w2pglijtbgiumolxsqq6s15frc20rvg',
#   'newstalkzb.co.nz',
#   'heather',
#   'du',
#   'plessis',
#   'allan',
#   'climate',
#   'change',
#   'big',
#   'emergency',
#   'nz',
#   'face',
#   'great',
#   'analogy',
#   'denesh',
#   'd’souza',
#   'parler',
#   'hope',
#   'trump',
#   'prevail',
#   'usa',
#   'rejoin',
#   'globalist',
#   'paris',
#   'climate',
#   'accord',
#   'socialist',
#   'green',
#   'new',
#   'deal',
#   'impose',
#   'biden',
#   'win',
#   'way',
#   'lance',
#   'armstrong',
#   'win',
#   'yes',
#   'armstrong',
#   'cross',
#   'finish',
#   'line',
#   'but',
#   'victory',
#   'bogus',
#   'cheat',
#   'that',
#   '’',
#   'be',
#   'say',
#   'biden',
#   '-PRON-',
#   'cheat',
#   'be',
#   'go',
#   'try',
#   'prove',
#   'court',
#   'https://parler.com/post/98fd9bec6b674a1695b70f9c1d7f0019',
#   'francis',
#   'menton',
#   'capture',
#   'moment',
#   'insightful',
#   'writing',
#   'basically',
#   'say',
#   'climate',
#   'realist',
#   'fight',
#   'not',
#   'live',
#   'lie',
#   'https://www.manhattancontrarian.com/blog/2020-11-19-the-climate-scam-what-we-are-up-against',
#   'manhattancontrarian.com',
#   'the',
#   'climate',
#   'scam',
#   'what',
#   '-PRON-',
#   'be',
#   'up',
#   'against',
#   'manhattan',
#   'contrarian',
#   'at',
#   'iloveco2',
#   'like',
#   'ten',
#   'million',
#   'rid',
#   'emotional',
#   'roller',
#   'coaster',
#   'presidential',
#   'election',
#   'for',
#   'obvious',
#   'reason',
#   'lot',
#   'stake',
#   'co2',
#   'climate',
#   'war',
#   'south',
#   'dakota',
#   'governor',
#   'kristi',
#   'noem',
#   'future',
#   'president',
#   'potential',
#   'good',
#   '4',
#   'minute',
#   'commentary',
#   'listen',
#   'https://youtu.be/c7byxvbl5jc',
#   'youtube.com',
#   'this',
#   'premature',
#   'finish',
#   'count',
#   'vote',
#   'south',
#   'dakota',
#   'governor',
#   '|',
#   'abc',
#   'news',
#   'youtube',
#   'keep',
#   'exhale',
#   'coal',
#   'simple',
#   'concentrate',
#   'million',
#   'year',
#   'old',
#   'solar',
#   'energy',
#   '-PRON-',
#   'ancient',
#   'sunshine',
#   'gift',
#   'human',
#   'provide',
#   'life',
#   'enhance',
#   'affordable',
#   'abundant',
#   'energy',
#   'thank',
#   'magic',
#   'mother',
#   'nature',
#   '🌎',
#   'twitter',
#   'facebook',
#   'google',
#   'arbiter',
#   'truth',
#   'complex',
#   'scientific',
#   'societal',
#   'issue',
#   'a',
#   'big',
#   'thank',
#   'co2',
#   'coalition',
#   'stand',
#   'free',
#   'speech',
#   'scientific',
#   'integrity',
#   'usa',
#   'senate',
#   'hearing',
#   'tomorrow',
#   '-PRON-',
#   'rare',
#   'bipartisan',
#   'support',
#   'reign',
#   'social',
#   'media',
#   'giant',
#   'bias',
#   'censorship',
#   'with',
#   'persistent',
#   'effort',
#   'diligence',
#   'overcome',
#   'huge',
#   'lie',
#   'co2',
#   'pollution',
#   'media',
#   'fabrication',
#   'propaganda',
#   'sell',
#   'the',
#   'successful',
#   'appointment',
#   'amy',
#   'coney',
#   'barrett',
#   'usa',
#   'supreme',
#   'court',
#   'mean',
#   'pathway',
#   'open',
#   'rescinding',
#   'contrived',
#   'obama',
#   'era',
#   'co2',
#   'endangerment',
#   'ruling',
#   'good',
#   'thing',
#   'happen',
#   'good',
#   'people',
#   'step',
#   'unreasonable',
#   'climate',
#   'realist',
#   'spring',
#   'step',
#   'moment',
#   'https://www.facebook.com/390205147852699/posts/1574141719459030/',
#   'co2',
#   'coalition',
#   'october',
#   '27',
#   '2020',
#   '10:30',
#   'am',
#   'social',
#   'medium',
#   'arbiter',
#   'truth',
#   'complex',
#   'scientific',
#   'societal',
#   'issue',
#   'read',
#   'late',
#   'gregory',
#   'wrightstone',
#   'climate',
#   'censorship',
#   'co2',
#   'coalition',
#   '|',
#   'meet',
#   'climate',
#   'scientists',
#   'that',
#   'social',
#   'media',
#   'censor',
#   'do',
#   'not',
#   'want',
#   '-PRON-',
#   'know',
#   'about',
#   'news',
#   'views',
#   'debates',
#   '27',
#   'oct',
#   '2020',
#   'meet',
#   'climate',
#   'scientists',
#   'that',
#   'social',
#   'media',
#   'censor',
#   'do',
#   'not',
#   'want',
#   '-PRON-',
#   'know',
#   'about',
#   'by',
#   'gregory',
#   'wrightstone',
#   'before',
#   'hunter',
#   'biden',
#   'new',
#   'york',
#   'post',
#   'twitter',
#   'imbroglio',
#   'blow',
#   'little',
#   'week',
#   'ago',
#   'primary',
#   'target',
#   'social',
#   'medium',
#   'censor',
#   'lef',
#   'co2',
#   'coalition',
#   '|',
#   'meet',
#   'climate',
#   'scientists',
#   'that',
#   'social',
#   'media',
#   'censor',
#   'do',
#   'not',
#   'want',
#   '-PRON-',
#   'know',
#   'about',
#   'news',
#   'views',
#   'debates',
#   '27',
#   'oct',
#   '2020',
#   'meet',
#   'climate',
#   'scientists',
#   'that',
#   'social',
#   'media',
#   'censor',
#   'do',
#   'not',
#   'want',
#   '-PRON-',
#   'know',
#   'about',
#   'by',
#   'gregory',
#   'wrightstone',
#   'before',
#   'hunter',
#   'biden',
#   'new',
#   'york',
#   'post',
#   'twitter',
#   'imbroglio',
#   'blow',
#   'little',
#   'week',
#   'ago',
#   'primary',
#   'target',
#   'social',
#   'medium',
#   'censor',
#   'lef',
#   'see',
#   'co2coalition.org',
#   'social',
#   'medium',
#   'arbiter',
#   'truth',
#   'complex',
#   'scientific',
#   'societal',
#   'issue',
#   'read',
#   'late',
#   'gregory',
#   'wrightstone',
#   'climate',
#   'censorship',
#   'co2',
#   'coalition',
#   '|',
#   'meet',
#   'climate',
#   'scientists',
#   'that',
#   'social',
#   'media',
#   'censor',
#   'do',
#   'not',
#   'want',
#   '-PRON-',
#   'know',
#   'about',
#   'news',
#   'views',
#   'debates',
#   '27',
#   'oct',
#   '2020',
#   'meet',
#   'climate',
#   'scientists',
#   'that',
#   'social',
#   'media',
#   'censor',
#   'do',
#   'not',
#   'want',
#   '-PRON-',
#   'know',
#   'about',
#   'by',
#   'gregory',
#   'wrightstone',
#   'before',
#   'hunter',
#   'biden',
#   'new',
#   'york',
#   'post',
#   'twitter',
#   'imbroglio',
#   'blow',
#   'little',
#   'week',
#   'ago',
#   'primary',
#   'target',
#   'social',
#   'medium',
#   'censor',
#   'lef',
#   'co2',
#   'coalition',
#   '|',
#   'meet',
#   'climate',
#   'scientists',
#   'that',
#   'social',
#   'media',
#   'censor',
#   'do',
#   'not',
#   'want',
#   '-PRON-',
#   'know',
#   'about',
#   'news',
#   'views',
#   'debates',
#   '27',
#   'oct',
#   '2020',
#   'meet',
#   'climate',
#   'scientists',
#   'that',
#   'social',
#   'media',
#   'censor',
#   'do',
#   'not',
#   'want',
#   '-PRON-',
#   'know',
#   'about',
#   'by',
#   'gregory',
#   'wrightstone',
#   'before',
#   'hunter',
#   'biden',
#   'new',
#   'york',
#   'post',
#   'twitter',
#   'imbroglio',
#   'blow',
#   'little',
#   'week',
#   'ago',
#   'primary',
#   'target',
#   'social',
#   'medium',
#   'censor',
#   'lef',
#   'see',
#   'co2coalition.org',
#   'of',
#   'climate',
#   'prophet',
#   'doom',
#   'obama',
#   'damaging',
#   'own',
#   '97',
#   'scientist',
#   'agree',
#   'lie',
#   'fortunately',
#   'shrill',
#   'petulant',
#   'wailing',
#   'stick',
#   'time',
#   'https://climatechangedispatch.com/obama-goes-full-on-climate-crazy-kids-will-face-an-uninhabitable-planet/?fbclid=iwar3kimhbliexerow5kpc6wzxqlvwrk38ffm_9_-eabbi2d9dcdidvyp80tq',
#   'climatechangedispatch.com',
#   'obama',
#   'go',
#   'full',
#   'on',
#   'climate',
#   'crazy',
#   'kid',
#   'will',
#   'face',
#   'an',
#   'uninhabitable',
#   'planet',
#   'new',
#   'zealand',
#   'choose',
#   'there',
#   'hope',
#   'change',
#   'voter',
#   'overwhelmingly',
#   'choose',
#   'elect',
#   'jacinda',
#   'ardern',
#   'continue',
#   'country',
#   '’s',
#   'journey',
#   'imaginary',
#   'green',
#   'leave',
#   'utopia',
#   'pay',
#   'utopia',
#   'miss',
#   'equation',
#   'prime',
#   'minister',
#   'jacinda',
#   'ardern',
#   'come',
#   'warm',
#   'caring',
#   'probably',
#   'make',
#   'dangerous',
#   'nasty',
#   'character',
#   'history',
#   'lead',
#   'people',
#   'disaster',
#   'unfortunately',
#   'law',
#   'say',
#   'new',
#   'zealand',
#   'remain',
#   'world',
#   'country',
#   'high',
#   'standard',
#   'living',
#   '-PRON-',
#   'possible',
#   'small',
#   'democracy',
#   'collectively',
#   'lose',
#   'mind',
#   'edge',
#   'cliff',
#   'look',
#   'like',
#   '’',
#   'exactly',
#   'be',
#   'sign',
#   'chinas',
#   'belt',
#   'road',
#   'plan',
#   'ban',
#   'gas',
#   'oil',
#   'exploration',
#   'carbon',
#   'dioxide',
#   'neutrality',
#   'slavish',
#   'adherence',
#   'un',
#   'gun',
#   'confiscation',
#   'curtail',
#   'free',
#   'speech',
#   'big',
#   'big',
#   'government',
#   'ground',
#   'hog',
#   'day',
#   'covid',
#   'lockdown',
#   '50',
#   'voter',
#   'want',
#   '-PRON-',
#   '’',
#   'new',
#   'reality',
#   'maybe',
#   '-PRON-',
#   'wrong',
#   'collective',
#   'wisdom',
#   'fellow',
#   'new',
#   'zealanders',
#   'right',
#   'way',
#   'work',
#   'good',
#   'cole',
#   'live',
#   'wonderment',
#   'bubble',
#   'great',
#   'place',
#   '-PRON-',
#   'spend',
#   'time',
#   '-PRON-',
#   'wonderment',
#   'magical',
#   'beauty',
#   'chemistry',
#   'planet',
#   'forest',
#   'lake',
#   'mountain',
#   'cover',
#   'snow',
#   'bird',
#   'ocean',
#   'star',
#   'sky',
#   'jet',
#   'plane',
#   'smart',
#   'phone',
#   'but',
#   'mission',
#   'pop',
#   'wonderment',
#   'bubble',
#   'senator',
#   'kamala',
#   'harris',
#   'try',
#   'night',
#   'testimony',
#   'hearing',
#   'appointment',
#   'usa',
#   'supreme',
#   'court',
#   'justice',
#   '-PRON-',
#   'expect',
#   'nastiness',
#   'heels',
#   'harris',
#   'not',
#   'disappoint',
#   'old',
#   'analogy',
#   'attempt',
#   'conflate',
#   'tobacco',
#   'company',
#   'denial',
#   'health',
#   'risk',
#   'smoking',
#   'fiction',
#   'human',
#   'generate',
#   'co2',
#   'change',
#   'climate',
#   '’',
#   'dangerous',
#   '’',
#   'fault',
#   'need',
#   'amazing',
#   'planet',
#   'gift',
#   'affordable',
#   'abundant',
#   'energy',
#   'save',
#   'self',
#   'what',
#   'miserable',
#   'place',
#   'harris',
#   'follower',
#   'come',
#   'live',
#   'bubble',
#   'gullibility',
#   'fatalism',
#   'superstition',
#   '-PRON-',
#   'iloveco2',
#   '’s',
#   'follower',
#   'mission',
#   'try',
#   'pop',
#   'warming',
#   'left',
#   'misery',
#   'bubble',
#   'message',
#   'optimism',
#   'scientific',
#   'honesty',
#   'at',
#   'essence',
#   'good',
#   'versus',
#   'evil',
#   '-PRON-',
#   'not',
#   'hate',
#   'co2',
#   'love',
#   'planet',
#   '🌎',
#   '❤',
#   '️',
#   '🌿',
#   'cole',
#   '-PRON-',
#   'unlimited',
#   'source',
#   'energy',
#   'main',
#   ...],
#  'ClimateChangeLIES': ['passportstampedhypocrite',
#   'tnc.news',
#   'climate',
#   'change',
#   'minister',
#   'spend',
#   '$',
#   '107,000',
#   'flight',
#   'iblameyoursuv',
#   'settledscience',
#   'sciencealert.com',
#   'unexpectedly',
#   'the',
#   'universe',
#   'be',
#   'get',
#   'hot',
#   'and',
#   'hot',
#   '-PRON-',
#   'expand',
#   'bravo',
#   'though',
#   '-PRON-',
#   'think',
#   'mistake',
#   'tides',
#   'foundation',
#   'sea',
#   'change',
#   'realclimatecrime',
#   'climatechangedispatch.com',
#   'epa',
#   'ask',
#   'doj',
#   'whether',
#   'green',
#   'groups',
#   'should',
#   'register',
#   'as',
#   'foreign',
#   'agents',
#   'carbon',
#   'credit',
#   'like',
#   'ask',
#   'eat',
#   'lunch',
#   'expect',
#   'passportstampedhypocrite',
#   'phys.org',
#   'climate',
#   'scientist',
#   'fly',
#   'researcher',
#   'global',
#   'study',
#   'suggest',
#   'settledscience',
#   'wattsupwiththat.com',
#   'the',
#   'lungs',
#   'gaia',
#   'auntie',
#   'force',
#   'retract',
#   'bust',
#   'tell',
#   'porkie',
#   'bravo',
#   'stopthelie',
#   'telegraph.co.uk',
#   'bbc',
#   'pull',
#   'climate',
#   'change',
#   'documentary',
#   'iplayer',
#   'farmer',
#   'complain',
#   'coverage',
#   'meat',
#   'trade',
#   'impartial',
#   'as',
#   'recently',
#   '2,000',
#   '1,000',
#   'year',
#   'ago',
#   'east',
#   'antarctica',
#   'warm',
#   '~6',
#   '°',
#   'c',
#   'warm',
#   'present',
#   'lake',
#   'fill',
#   '60',
#   '80',
#   'meter',
#   'meltwater',
#   'exist',
#   'lake',
#   'basin',
#   'today',
#   'paging',
#   'michael',
#   'mann',
#   'settledscience',
#   'stopthelies',
#   'thegwpf.com',
#   'east',
#   'antarctica',
#   '6',
#   '°',
#   'c',
#   'warm',
#   'today',
#   'medieval',
#   'warm',
#   'period',
#   'new',
#   'study',
#   'the',
#   'global',
#   'warming',
#   'policy',
#   'forum',
#   'gwpf',
#   'how',
#   'start',
#   'explain',
#   'general',
#   'consensus',
#   'climate',
#   'change',
#   'flawed',
#   'reddit.com',
#   'introduce',
#   'people',
#   'think',
#   'differently',
#   'climate',
#   'change',
#   'new',
#   'study',
#   'find',
#   'mediterranean',
#   'water',
#   '2c',
#   'warm',
#   'present',
#   'roman',
#   'time',
#   'iblameyoursuv',
#   'nature.com',
#   'persistent',
#   'warm',
#   'mediterranean',
#   'surface',
#   'water',
#   'roman',
#   'period',
#   'green',
#   'energy',
#   'a',
#   'sound',
#   'investment',
#   'greenfraud',
#   'stopthelies',
#   'standard.co.uk',
#   'national',
#   'grid',
#   'warn',
#   'short',
#   'supply',
#   'electricity',
#   'day',
#   'settledscience',
#   'youtube.com',
#   'the',
#   'speech',
#   'that',
#   'be',
#   'suppose',
#   'be',
#   'debate',
#   'with',
#   'michael',
#   'mann',
#   'a',
#   'great',
#   'surface',
#   'temperature',
#   '5c',
#   'earth',
#   'consider',
#   'good',
#   'life',
#   'wait',
#   'settledscience',
#   'news.sky.com',
#   'scientists',
#   'discover',
#   '24',
#   'superhabitable',
#   'planet',
#   'condition',
#   'good',
#   'life',
#   'earth',
#   'greenie',
#   'with',
#   'a',
#   'streak',
#   'of',
#   'pure',
#   'evil',
#   'update',
#   'former',
#   'climate',
#   'minister',
#   'catherine',
#   'mckenna',
#   'aka',
#   'climate',
#   'barbie',
#   'attend',
#   'illeagal',
#   'cockfighting',
#   'eat',
#   'dog',
#   'meat',
#   'indonesia',
#   '1995',
#   'cockfighting',
#   'outlaw',
#   'country',
#   '14',
#   'year',
#   "video'd",
#   'bribe',
#   'way',
#   'event',
#   'bird',
#   'tear',
#   'shred',
#   'result',
#   'painful',
#   'death',
#   '-PRON-',
#   'see',
#   'eat',
#   'dog',
#   'the',
#   'dog',
#   'likely',
#   'torture',
#   'death',
#   'cook',
#   'aware',
#   '-PRON-',
#   'remove',
#   'office',
#   'immediately',
#   '-PRON-',
#   'ccl',
#   'surprised',
#   'word',
#   'people',
#   'want',
#   'world',
#   'totalitarian',
#   'government',
#   'equally',
#   'poor',
#   'be',
#   'charge',
#   'greenisthenewred',
#   'thepostmillennial.com',
#   'watch',
#   'trudeau',
#   'cabinet',
#   'minister',
#   'eat',
#   'dog',
#   'meat',
#   'attend',
#   'illegal',
#   'cockfight',
#   'indonesia',
#   'foreign',
#   'fund',
#   'alarmist',
#   'update',
#   'https://bit.ly/2zv1m4m',
#   'greenisthenewred',
#   'telegraph.co.uk',
#   'tory',
#   'peer',
#   'pay',
#   '£',
#   '6',
#   'm',
#   'russian',
#   'energy',
#   'company',
#   'link',
#   'billionaire',
#   'friend',
#   'vladimir',
#   'putin',
#   'youtube.com',
#   'return',
#   'eden',
#   'online',
#   'premiere',
#   'co2',
#   'induced',
#   'coffee',
#   'apocalypse',
#   'update',
#   'https://www.bloomberg.com/amp/news/articles/2020-09-15/brazil-is-awash-with-coffee-and-running-out-of-space-to-store-it?__twitter_impression=true',
#   'climatecrops',
#   'bloomberg.com',
#   'brazil',
#   'be',
#   'run',
#   'out',
#   'space',
#   'store',
#   '-PRON-',
#   'coffee',
#   'alarmist',
#   'openly',
#   'advocate',
#   'state',
#   'permanent',
#   'totalitarianism',
#   'fight',
#   'climate',
#   'change',
#   'greenisthenewred',
#   'express.co.uk',
#   'dream',
#   'on!’',
#   'speaker',
#   'lindsay',
#   'hoyle',
#   'slap',
#   'lockdown',
#   'style',
#   'climate',
#   'change',
#   'rule',
#   'the',
#   'state',
#   'california',
#   'sentence',
#   '200',
#   'innocent',
#   'people',
#   'burn',
#   'death',
#   'woman',
#   'child',
#   'military',
#   'not',
#   'have',
#   'undoubtedly',
#   'brave',
#   'action',
#   'national',
#   'gaurd',
#   'alarmists',
#   'medium',
#   'claim',
#   'death',
#   'cause',
#   'climate',
#   'change',
#   'bravo',
#   'regional',
#   'military',
#   'affairs',
#   'committee',
#   'september',
#   '10',
#   '2020',
#   '6:26',
#   'am',
#   'the',
#   'state',
#   'california',
#   '’s',
#   'wildfire',
#   'emergency',
#   'management',
#   'agency',
#   'calfire',
#   'alert',
#   '200',
#   'people',
#   'entirely',
#   'encircle',
#   'fire',
#   '-PRON-',
#   'formally',
#   'declare',
#   'ability',
#   'calfire',
#   'save',
#   'effectively',
#   'tell',
#   'presume',
#   'likely',
#   'die',
#   'the',
#   'ca',
#   'national',
#   'guard',
#   'spin',
#   '2',
#   'helicopter',
#   'blackhawk',
#   'chinook',
#   'head',
#   'help',
#   'on',
#   'ride',
#   'calfire',
#   'call',
#   'repeatedly',
#   'tell',
#   'base',
#   'dangerous',
#   'flying',
#   'night',
#   'vision',
#   'high',
#   'cross',
#   'wind',
#   'smoke',
#   'burn',
#   'ember',
#   'rough',
#   'terrain',
#   'ca',
#   'ng',
#   'take',
#   'land',
#   'time',
#   'rescue',
#   '200',
#   'people',
#   '-PRON-',
#   'effort',
#   'capture',
#   'picture',
#   'look',
#   'positively',
#   'apocalyptic',
#   'huge',
#   'huge',
#   'prop',
#   'ca',
#   'ng',
#   'pretty',
#   'remarkable',
#   'meanwhile',
#   'british',
#   'columbia',
#   'https://governmentofbc.maps.arcgis.com/apps/webappviewer/index.html?id=a1e7b1ecb1514974a9ca00bdbfffa3b1&mobilebreakpoint=300',
#   'climatefires',
#   'unprecedented',
#   'co2',
#   'level',
#   'updare',
#   'stopthelie',
#   'an',
#   'insightful',
#   'article',
#   'philosophical',
#   'root',
#   'craziness',
#   'pseudoscience',
#   'society',
#   'to',
#   'reason',
#   'rely',
#   'evidence',
#   'seek',
#   'consistency',
#   'insist',
#   'individual',
#   'ownership',
#   'life',
#   'feature',
#   'oppressive',
#   'culture',
#   'settledscience',
#   'stopthelies',
#   'financialpost.com',
#   'apocalyptic',
#   'science',
#   'how',
#   'west',
#   'destroy',
#   'global',
#   'warming',
#   'oregon',
#   "'s",
#   'fire',
#   'bad',
#   'update',
#   'climatefires',
#   'oregonlive.com',
#   'oregon',
#   '’s',
#   'historic',
#   'wildfire',
#   'unusual',
#   'unprecedented',
#   'a',
#   'thorough',
#   'takedown',
#   'taxpayer',
#   'fund',
#   'msm',
#   'fakenews',
#   'lie',
#   'regard',
#   'legate',
#   'hire',
#   'noaa',
#   'taxdollarsatwork',
#   'bravo',
#   'stoptheli',
#   'wattsupwiththat.com',
#   'real',
#   'climate',
#   'science',
#   'from',
#   'david',
#   'legate',
#   'seems',
#   'to',
#   'scare',
#   'the',
#   'media',
#   'will',
#   'it',
#   'scare',
#   'noaa',
#   'co2',
#   'totally',
#   'explain',
#   'fire',
#   'pattern',
#   'see',
#   'be',
#   'completely',
#   'sure',
#   'trace',
#   'co2',
#   'explain',
#   'pattern',
#   'fire',
#   'show',
#   'https://t.co/dr5w7n4kyr',
#   'finally',
#   'common',
#   'sense',
#   'mercurynews.com',
#   'california',
#   'fire',
#   'state',
#   'fed',
#   'agree',
#   'thin',
#   'million',
#   'acre',
#   'forest',
#   'co2',
#   'induce',
#   'crop',
#   'failure',
#   'update',
#   'climatecrops',
#   'wsj.com',
#   'u.s.',
#   'corn',
#   'supply',
#   'grow',
#   'record',
#   'crop',
#   'yield',
#   'green',
#   'energy',
#   'a',
#   'sound',
#   'investment',
#   'reverserobinhood',
#   'greenfraud',
#   'stopthelies',
#   'thegwpf.com',
#   'california',
#   'doom',
#   'frequent',
#   'blackout',
#   'due',
#   'to',
#   'battery',
#   'shortage',
#   'the',
#   'global',
#   'warming',
#   'policy',
#   'forum',
#   'gwpf',
#   'have',
#   'anybody',
#   'see',
#   '50',
#   'million',
#   'climate',
#   'refugee',
#   'suppose',
#   'appear',
#   '10',
#   'year',
#   'ago',
#   'alarmistpredictions',
#   'theguardian.com',
#   '50',
#   'm',
#   'environmental',
#   'refugee',
#   'end',
#   'decade',
#   'un',
#   'warn',
#   'covid-19',
#   'blame',
#   'lawnmower',
#   'well',
#   'add',
#   'list',
#   'warmlist',
#   'thehill.com',
#   '-PRON-',
#   'ignore',
#   'link',
#   'covid-19',
#   'warming',
#   'planet',
#   'the',
#   'un',
#   'move',
#   'implement',
#   'duck',
#   'speak',
#   'how',
#   'orwellian',
#   'greenisthenewred',
#   'wevealwaysbeenatwarwitheastasia',
#   'twitter.com',
#   'united',
#   'nations',
#   'twitter',
#   'green',
#   'censor',
#   'want',
#   'michael',
#   'moore',
#   'film',
#   'planet',
#   'humans',
#   'remove',
#   'youtube',
#   'this',
#   'video',
#   'explain',
#   'drive',
#   'censor',
#   'greenisthenewred',
#   'wevealwaysbeenatwarwitheastasia',
#   'youtube.com',
#   'planet',
#   'greens',
#   'eco',
#   'activist',
#   'turn',
#   '50',
#   'consensus',
#   'settledscience',
#   'the',
#   'north',
#   'atlantic',
#   'warm',
#   'cool',
#   'new',
#   'study',
#   'a',
#   'massive',
#   'cooling',
#   'of',
#   '2',
#   '°',
#   'c',
#   'in',
#   '8',
#   'year',
#   '2008',
#   '2016',
#   'have',
#   'jolt',
#   'large',
#   'region',
#   'of',
#   'the',
#   'north',
#   'atlantic',
#   'notrickszone.com',
#   'new',
#   'study',
#   'a',
#   'massive',
#   'cooling',
#   'of',
#   '2',
#   '°',
#   'c',
#   'in',
#   '8',
#   'year',
#   '2008',
#   '2016',
#   'have',
#   'jolt',
#   'large',
#   'region',
#   'of',
#   'the',
#   'north',
#   'atlantic',
#   'wow',
#   'hayhoe',
#   'admit',
#   'nearly',
#   'climate',
#   'scientist',
#   'feel',
#   'bitter',
#   'pleasure',
#   'fire',
#   'flood',
#   'drought',
#   'storm',
#   'etc',
#   'happen',
#   'yet',
#   'be',
#   'increase',
#   'looneyleft',
#   'alarmist',
#   'try',
#   'financially',
#   'destroy',
#   'naomi',
#   'seibt',
#   'silence',
#   'let',
#   'help',
#   'stopthelie',
#   'greenisthenewred',
#   'wattsupwiththat.com',
#   'monckton',
#   'naomi',
#   'seibt',
#   'anti',
#   'greta',
#   'need',
#   'financial',
#   'support',
#   'looneyleft',
#   'gript',
#   'april',
#   '22',
#   '2020',
#   '4:47',
#   'am',
#   'journalists',
#   'like',
#   'fintan',
#   'o’toole',
#   'human',
#   'virus',
#   'earth',
#   '’s',
#   'perspective',
#   'tim',
#   'jackson',
#   'comment',
#   '’',
#   'wrong',
#   'gript',
#   'wikipedia',
#   'bowl',
#   'cherry',
#   'no',
#   'wonder',
#   'alarmist',
#   'rely',
#   'analyze',
#   '1,923,575',
#   'wikipedia',
#   'article',
#   'cite',
#   'total',
#   '841,821',
#   'scientific',
#   'article',
#   'find',
#   'cite',
#   'article',
#   '58',
#   'uncited',
#   'untested',
#   'subsequent',
#   'study',
#   'remainder',
#   'wide',
#   'variability',
#   'biorxiv.org',
#   'measure',
#   'quality',
#   'scientific',
#   'reference',
#   'wikipedia',
#   'analysis',
#   '80',
#   'm',
#   'citation',
#   '800,000',
#   'scientific',
#   'article',
#   'hottestyearevah',
#   'iceagenow.info',
#   'hard',
#   'freezes',
#   'hammer',
#   'italian',
#   'orchards'],
#  'australianclimatemadness': ['on',
#   'behalf',
#   'environmentalist',
#   '-PRON-',
#   'like',
#   'formally',
#   'apologize',
#   'climate',
#   'scare',
#   'create',
#   '30',
#   'year',
#   'share',
#   'widely',
#   'please',
#   'let',
#   '-PRON-',
#   'message',
#   'australianclimatemadness.com',
#   'on',
#   'behalf',
#   'environmentalist',
#   '-PRON-',
#   'like',
#   'formally',
#   'apologize',
#   'climate',
#   'scare',
#   'create',
#   '30',
#   'years’',
#   'craig',
#   'kelly',
#   'june',
#   '30',
#   '2020',
#   '3:37',
#   'am',
#   'former',
#   'climate',
#   'alarmist',
#   'offer',
#   'apology',
#   'for',
#   'phoney',
#   'climate',
#   'scare',
#   'campaign',
#   '’men',
#   'mad',
#   'herd',
#   'regain',
#   'sens',
#   'slowly',
#   'time',
#   'who',
#   'apologise',
#   'peddle',
#   'phoney',
#   'climate',
#   'alarmism',
# ...
#   'asia',
#   'western',
#   'russia',
#   'western',
#   'us',
#   'southern',
#   'andes',
#   'climate',
#   'change',
#   'place',
#   'water',
#   'resource',
#   'basin',
#   'risk',
#   'indicate',
#   'need',
#   'adapt',
#   'water',
#   'management',
#   'nature.com',
#   'agricultural',
#   'risk',
#   'change',
#   'snowmelt',
#   'climate',
#   'warming',
#   'cause',
#   'mountain',
#   'precipitation',
#   'fall',
#   'snow',
#   'hydrologic',
#   'simulation',
#   'predict',
#   'high',
#   'end',
#   'emission',
#   'scenario',
#   'decrease',
#   'predictability',
#   'seasonal',
#   'water',
#   'resource',
#   'western',
#   'united',
#   'states',
#   'low',
#   'elevation',
#   'coastal',
#   'area',
#   'impact',
#   'strongly',
#   'nature.com',
#   'drought',
#   'predictable',
#   'decline',
#   'future',
#   'snowpack',
#   'nitrogen',
#   'removal',
#   'occur',
#   'primarily',
#   'microbially',
#   'mediate',
#   'denitrification',
#   'produce',
#   'ghg',
#   'n2o',
#   'anaerobic',
#   'ammonium',
#   'oxidation',
#   'anammox',
#   'warm',
#   'stimulate',
#   'denitrification',
#   'relative',
#   'annamox',
#   'subtropical',
#   'sediment',
#   'indicate',
#   'warming',
#   'lead',
#   'great',
#   'n2o',
#   'production',
#   'nature.com',
#   'warming',
#   'stimulate',
#   'sediment',
#   'denitrification',
#   'expense',
#   'anaerobic',
#   'ammonium',
#   'oxidation',
#   'despite',
#   'strict',
#   'control',
#   'precursor',
#   'emission',
#   'ozone',
#   'air',
#   'pollution',
#   'decrease',
#   'europe',
#   'recent',
#   'decade',
#   'this',
#   'largely',
#   'attribute',
#   'water',
#   'stress',
#   'vegetation',
#   'heatwaf',
#   'drought',
#   'plant',
#   'effective',
#   'ozone',
#   'removal',
#   'stoma',
#   'worsen',
#   'peak',
#   'ozone',
#   'pollution',
#   'episode',
#   'nature.com',
#   'vegetation',
#   'feedback',
#   'drought',
#   'exacerbate',
#   'ozone',
#   'air',
#   'pollution',
#   'extreme',
#   'europe',
#   'this',
#   'analysis',
#   'global',
#   'climate',
#   'policy',
#   'report',
#   'show',
#   'economic',
#   'idea',
#   'shape',
#   'climate',
#   'policy',
#   'the',
#   'author',
#   'find',
#   'shift',
#   'neoclassical',
#   'dominance',
#   'diversified',
#   'discourse',
#   'expand',
#   'policy',
#   'choice',
#   'market',
#   'base',
#   'policy',
#   'include',
#   'green',
#   'innovation',
#   'industrial',
#   'policy',
#   'nature.com',
#   'the',
#   'evolution',
#   'idea',
#   'global',
#   'climate',
#   'policy',
#   'erosion',
#   'major',
#   'problem',
#   'face',
#   'sandy',
#   'beach',
#   'probably',
#   'worsen',
#   'climate',
#   'change',
#   'sea',
#   'level',
#   'rise',
#   'half',
#   'world',
#   '’s',
#   'beach',
#   'densely',
#   'populate',
#   'area',
#   'disappear',
#   'end',
#   'century',
#   'current',
#   'trend',
#   'mitigation',
#   'lessen',
#   'retreat',
#   '40',
#   'nature.com',
#   'sandy',
#   'coastline',
#   'threat',
#   'erosion',
#   'cost',
#   'achieve',
#   'climate',
#   'target',
#   'uncertain',
#   'a',
#   'metamodel',
#   'estimate',
#   'median',
#   'cost',
#   'limit',
#   'warming',
#   '2',
#   '°',
#   'c',
#   '1.5',
#   '°',
#   'c',
#   'us$',
#   '15',
#   'trillion',
#   'us$',
#   '30',
#   'trillion',
#   'uncertainty',
#   'emission',
#   'reduction',
#   'cost',
#   'dominate',
#   'level',
#   'climate',
#   'system',
#   'uncertainty',
#   'dominate',
#   'high',
#   'warming',
#   'level',
#   'nature.com',
#   'the',
#   'cost',
#   'achieve',
#   'climate',
#   'target',
#   'source',
#   'uncertainty',
#   'concrete',
#   'production',
#   'emit',
#   'high',
#   'level',
#   'ghg',
#   '-PRON-',
#   'cause',
#   'air',
#   'pollution',
#   'emission',
#   'particulate',
#   'matter',
#   'nitrogen',
#   'sulfur',
#   'oxide',
#   'ghg',
#   'emission',
#   'because',
#   'climate',
#   'health',
#   'damage',
#   'near',
#   '75',
#   'industry',
#   'value',
#   'nature.com',
#   'climate',
#   'health',
#   'damage',
#   'global',
#   ...],
#  'ClimateChangeCauses': ['get',
#   'important',
#   'text',
#   'message',
#   'reminder',
#   'election',
#   'day',
#   'join',
#   'brigade',
#   'click',
#   'start',
#   'brigade.com/ballot',
#   'election',
#   'day',
#   'make',
#   'voice',
#   'vote',
#   'count',
#   'brigade.com/ballot',
#   'wow',
#   'this',
#   'go',
#   'huge',
#   'anyone',
#   'plan',
#   'attend',
#   'washingtonpost.com',
#   'for',
#   'pope',
#   'francis',
#   '’s',
#   'd.c.',
#   'visit',
#   'environmental',
#   'rally',
#   '200',
#   'k',
#   'plan',
#   'great',
#   'video',
#   'friend',
#   'forecast',
#   'fact',
#   'check',
#   'sure',
#   'share',
#   'check',
#   'inspiring',
#   'story',
#   'survivor',
#   'historic',
#   'flooding',
#   'tx',
#   'fight',
#   'climate',
#   'truth',
#   'guess',
#   'sign',
#   'support',
#   'fight',
#   'http://bit.ly/tx_flood',
#   'oil',
#   'change',
#   'u.s.',
#   'july',
#   '14',
#   '2015',
#   '8:00',
#   'pm',
#   'check',
#   'inspiring',
#   'story',
#   'survivor',
#   'historic',
#   'flooding',
#   'tx',
#   'fight',
#   'climate',
#   'truth',
#   'guess',
#   'sign',
#   'support',
#   'fight',
#   'http://bit.ly/tx_flood',
#   'break',
#   'global',
#   'warming',
#   'happen',
#   'in',
#   'news',
#   'water',
#   'wet',
#   'iflscience.com',
#   'nasa',
#   'study',
#   'find',
#   'there',
#   'be',
#   'no',
#   'pause',
#   'in',
#   'climate',
#   'change',
#   'whoa',
#   'incredible',
#   'beauty',
#   'match',
#   'incredible',
#   'horror',
#   'a',
#   'piece',
#   'size',
#   'manhattan',
#   'break',
#   'free',
#   'greenland',
#   'glacier',
#   'retreat',
#   '10',
#   'year',
#   '100',
#   'year',
#   'climate',
#   'change',
#   'disrupt',
#   'planet',
#   "'s",
#   'critical',
#   'cycle',
#   'upworthy',
#   'may',
#   '15',
#   '2015',
#   '7:14',
#   'pm',
#   'exposure',
#   'labs',
#   'take',
#   'camera',
#   'remote',
#   'area',
#   'greenland',
#   'record',
#   'terrifying',
#   'learn',
#   'film',
#   'http://www.exposurelabs.com',
#   'rainforest',
#   'action',
#   'network',
#   'launch',
#   'campaign',
#   'ask',
#   'pepsico',
#   'cut',
#   'conflict',
#   'palm',
#   'oil',
#   'protect',
#   'orangutans',
#   'sign',
#   'petition',
#   'http://oncaus.es/1juhicr',
#   'explode',
#   'rail',
#   'car',
#   'just',
#   'reason',
#   'need',
#   'reduce',
#   'dependance',
#   'oil',
#   'http://oncaus.es/1jld7sa',
#   'www.causes.com',
#   'sign',
#   'the',
#   'petition',
#   'to',
#   'end',
#   'the',
#   'use',
#   'of',
#   'dot',
#   '111',
#   'tank',
#   'cars',
#   'here',
#   'be',
#   'awesome',
#   'petition',
#   'folk',
#   'greenpeace',
#   'usa',
#   'ask',
#   'twitter',
#   'ceo',
#   'dick',
#   'costolo',
#   'power',
#   'data',
#   'center',
#   '100',
#   'renewable',
#   'energy',
#   'sign',
#   'http://oncaus.es/1jlbzht',
#   'www.causes.com',
#   'sign',
#   'the',
#   'petition',
#   'to',
#   'twitter',
#   'ceo',
#   'dick',
#   'costolo',
#   'amongst',
#   'reason',
#   'h',
#   't',
#   'moms',
#   'clean',
#   'air',
#   'force',
#   'happy',
#   'mother',
#   "'s",
#   'day',
#   'h',
#   't',
#   'rainforest',
#   'action',
#   'network',
#   'cnn',
#   'try',
#   'bill',
#   'nye',
#   'the',
#   'science',
#   'guy',
#   'look',
#   'stupid',
#   'fail',
#   'miserably',
#   'http://oncaus.es/1nlyb9d',
#   'www.policymic.com',
#   'this',
#   'meme',
#   'sum',
#   'up',
#   'everything',
#   'that',
#   'be',
#   'wrong',
#   'with',
#   'climate',
#   'change',
#   'deniers',
#   'that',
#   'solar',
#   'option',
#   'look',
#   'pretty',
#   'attractive',
#   'h',
#   't',
#   'climate',
#   'reality',
#   '-PRON-',
#   'try',
#   'be',
#   'frickin',
#   'hard',
#   'h',
#   't',
#   'the',
#   'pieces',
#   'fit',
#   'thank',
#   'friendly',
#   'funny',
#   'reminder',
#   'free',
#   '-PRON-',
#   'mind',
#   'think',
#   'here',
#   'be',
#   '5',
#   'reason',
#   'nokxl',
#   'thank',
#   'takepart.com',
#   'image!.',
#   'because',
#   'science',
#   'thank',
#   'climate',
#   'reality',
#   'image!.',
#   '-PRON-',
#   'admit',
#   'be',
#   'pretty',
#   'insane',
#   'thank',
#   'mosaic',
#   'image!.',
#   'here',
#   'be',
#   'flowchart',
#   'disbelieve',
#   'friend',
#   'thank',
#   'the',
#   'climate',
#   'desk',
#   'infographic',
#   'climatechange',
#   'climate',
#   'reality',
#   'start',
#   'campaign',
#   'support',
#   'carbon',
#   'pollution',
#   'standard',
#   'new',
#   'power',
#   'plant',
#   'sign',
#   'petition',
#   'epa',
#   'http://oncaus.es/1k6fsnc',
#   'uhh',
#   'be',
#   'thank',
#   'climate',
#   'reality',
#   'image',
#   'climatechange',
#   'well',
#   'say',
#   'bill',
#   'maher',
#   'thank',
#   'climate',
#   'reality',
#   'image',
#   'nice',
#   'day',
#   '>',
#   'oil',
#   'spill',
#   'right',
#   'thank',
#   'beware',
#   'image',
#   'photo!.',
#   'plus',
#   'squeaky',
#   'sound',
#   'make',
#   'hoooorrrrible',
#   'thank',
#   'up',
#   'mountaineers',
#   'give',
#   'shit',
#   'nature',
#   'image!.',
#   'former',
#   'vice',
#   'president',
#   'al',
#   'gore',
#   'say',
#   'best!.',
#   '48',
#   'lb',
#   '-PRON-',
#   'not',
#   'thank',
#   'tip',
#   '-PRON-',
#   'be',
#   'eco',
#   'warrior!.',
#   'share',
#   'agree',
#   'thank',
#   '-PRON-',
#   'heart',
#   'climate',
#   'scientists',
#   'photo',
#   'if',
#   'knowledge',
#   '=',
#   'power',
#   'power',
#   'stop',
#   'climate',
#   'change',
#   'thanks',
#   'climate',
#   'reality',
#   'image!.',
#   'free',
#   'say',
#   'whaaa',
#   'thank',
#   'more',
#   'tree',
#   'less',
#   'assholes',
#   'image!.',
#   'valid',
#   'point',
#   'not',
#   'ya',
#   'think',
#   'thank',
#   'more',
#   'tree',
#   'less',
#   'assholes',
#   'image!.',
#   'good',
#   'thing',
#   'be',
#   'people',
#   'like',
#   'actually',
#   'care',
#   'thank',
#   'image',
#   'global',
#   'citizen',
#   'do',
#   'agree',
#   'h',
#   't',
#   'the',
#   'pieces',
#   'fit',
#   'www.causes.com',
#   '1.3',
#   'million',
#   'count',
#   'carbon',
#   'rule',
#   'tomorrow',
#   'people',
#   'world',
#   'join',
#   'hand',
#   'create',
#   '24',
#   'hour',
#   'reality',
#   '-PRON-',
#   'hope',
#   'will',
#   'join',
#   'together',
#   'be',
#   'go',
#   'focus',
#   'world',
#   "'s",
#   'attention',
#   'scope',
#   'scale',
#   'impact',
#   'climate',
#   'crisis',
#   '24',
#   'hour',
#   'reality',
#   'begin',
#   '7',
#   'p.m.',
#   'central',
#   'time',
#   'wednesday',
#   'september',
#   '14',
#   'over',
#   'course',
#   'day',
#   '24',
#   'presentation',
#   '24',
#   'time',
#   'zone',
#   '13',
#   'language',
#   'use',
#   'simple',
#   'tool',
#   'set',
#   '24',
#   'hour',
#   'reality',
#   'bring',
#   'the',
#   'climate',
#   'reality',
#   'project',
#   'learn',
#   'http://climaterealityproject.org',
#   'www.causes.com',
#   '24',
#   'hour',
#   'reality',
#   'the',
#   'u.s.',
#   'environmental',
#   'protection',
#   'agency',
#   'epa',
#   'plan',
#   'limit',
#   'greenhouse',
#   'gas',
#   'pollution',
#   'big',
#   'fossil',
#   'fuel',
#   'industry',
#   'like',
#   'power',
#   'plant',
#   'petroleum',
#   'refinery',
#   'these',
#   'industry',
#   'account',
#   '40',
#   'global',
#   'warming',
#   'pollution',
#   'u.s.',
#   'make',
#   'large',
#   'source',
#   'emission',
#   'http://acp.repoweramerica.org/contact-epa-sgw',
#   'here',
#   '’',
#   'come',
#   'between',
#   'march',
#   '18',
#   'if',
#   'buy',
#   'valentine',
#   '’s',
#   'gift',
#   'because',
#   'alliance',
#   'climate',
#   'protection',
#   'automatically',
#   'get',
#   '$',
#   '10',
#   'purchase',
#   'shop',
#   'gift',
#   'http://www.causes.com/valentines/24?ref=com24',
#   'the',
#   'present',
#   'price',
#   'feel',
#   'good',
#   'gift',
#   'support',
#   'work',
#   'solve',
#   'climate',
#   'crisis',
#   '-PRON-',
#   '’',
#   'simple',
#   'use',
#   'link',
#   'buy',
#   'valentine',
#   '’s',
#   'day'],
#  'GlobalwarmingEva': ['mon',
#   'feb',
#   '1',
#   'feb',
#   '14',
#   'solutions',
#   'for',
#   'wild',
#   'life',
#   'protection',
#   'in',
#   'road',
#   'accident',
#   'hi',
#   'attention',
#   'hope',
#   '.we',
#   'need',
#   'guy',
#   'page',
#   'editor',
#   'country',
#   'spread',
#   'awareness',
#   'global',
#   'warming',
#   'certification',
#   'to',
#   'communicate',
#   'properly',
#   'ongoing',
#   'program',
#   'help',
#   'manage',
#   'intrested',
#   'one',
#   'mail',
#   'give',
#   'address',
#   'afzalhasnain33@gmail.com',
#   'only',
#   '48',
#   'hour',
#   'send',
#   'cv',
#   'reseacrh',
#   'proposal',
#   'more',
#   'news',
#   'come',
#   'share',
#   'alott',
#   'columbia',
#   'university',
#   'develop',
#   'artificial',
#   'tree',
#   'capability',
#   'soak',
#   'carbon',
#   'dioxide',
#   '1000',
#   'time',
#   'efficiently',
#   'natural',
#   'leaf',
#   'use',
#   'photosynthesis',
#   'by',
#   'estimation',
#   'artificial',
#   'tree',
#   'perform',
#   'job',
#   '368',
#   'natural',
#   'tree',
#   'further',
#   'advancement',
#   'progress',
#   'globalise',
#   'concept',
#   'a',
#   'beautiful',
#   'peaceful',
#   'giant',
#   'be',
#   'run',
#   'over',
#   'by',
#   'violent',
#   'selfish',
#   'pest',
#   'destructive',
#   'specie',
#   'overpopulate',
#   'planet',
#   'make',
#   'bad',
#   'nuisance',
#   'invade',
#   'home',
#   'animal',
#   'wild',
#   'danger',
#   '3',
#   'specie',
#   'die',
#   'hour',
#   'suffer',
#   'sixth',
#   'mass',
#   'extinction',
#   'build',
#   'mega',
#   'farm',
#   'raise',
#   'animal',
#   'kill',
#   'bad',
#   'culprit',
#   'country',
#   'human',
#   'kill',
#   'more',
#   'animal',
#   'in',
#   '5',
#   'day',
#   'than',
#   'all',
#   'human',
#   'have',
#   'be',
#   'kill',
#   'in',
#   'history',
#   'courtesy',
#   '@knowledgecentral',
#   'life',
#   '💚',
#   'good',
#   'work',
#   '👍',
#   'federal',
#   'government',
#   'germany',
#   'the',
#   'tree',
#   'first',
#   '🌳',
#   '🌍',
#   '🌳',
#   'when',
#   'know',
#   'value',
#   'tree',
#   'alternative',
#   'instead',
#   'cut',
#   'tree',
#   'respect_nature',
#   'sad',
#   'reality',
#   'today',
#   "'s",
#   'world',
#   '😥',
#   '🌍',
#   'please',
#   'plant',
#   'tree',
#   'save',
#   'future',
#   '🌳',
#   '❤',
#   '🌳',
#   'the',
#   'wonderful',
#   'saiga',
#   'antelope',
#   'classify',
#   'critically',
#   'endangered',
#   'iucn',
#   'red',
#   'list',
#   'threaten',
#   'specie',
#   'save',
#   'nature',
#   'stop',
#   'global',
#   'warming',
#   'this',
#   'tree',
#   'important',
#   '😢',
#   '🙏',
#   '🌳',
#   'please',
#   'plant',
#   'tree',
#   'plant',
#   'hope',
#   '🌳',
#   '❤',
#   '🌳',
#   'help',
#   'plant',
#   'trees',
#   '🌳',
#   '🌍',
#   '🌳',
#   'when',
#   'picture',
#   'say',
#   'more',
#   'than',
#   '1000',
#   'word',
#   '😥',
#   'please',
#   'plant',
#   'tree',
#   'plant',
#   'hope',
#   '🌳',
#   '❤',
#   '🌳',
#   'help',
#   'plant',
#   'trees',
#   '🌍',
#   'good',
#   'job',
#   'art',
#   '👏',
#   'almost',
#   'country',
#   'earth',
#   'sign',
#   'paris',
#   'climate',
#   'agreement',
#   '-PRON-',
#   'say',
#   'human',
#   'intelligent',
#   'live',
#   'being',
#   'planet',
#   'if',
#   'intelligent',
#   'claim',
#   'predilection',
#   'want',
#   'destroy',
#   'natural',
#   'environment',
#   'specie',
#   'childinspiration',
#   'ethiopia',
#   'plant',
#   '5',
#   'billion',
#   'million',
#   'plant',
#   'year',
#   'and',
#   'ethiopia',
#   'plant',
#   '4',
#   'billion',
#   'million',
#   'plant',
#   'year',
#   'and',
#   'ethiopia',
#   'plan',
#   'plant',
#   '6',
#   'billion',
#   'million',
#   'plant',
#   'year',
#   '1',
#   'billion',
#   'neabor',
#   'country',
#   'if',
#   'not',
#   'know',
#   'ethiopia',
#   'locate',
#   'horn',
#   'africal',
#   'eastern',
#   'africa',
#   'please',
#   'share',
#   'lesson',
#   'self',
#   'follower',
#   'country',
#   'malaysia',
#   "'s",
#   'sumatran',
#   'rhino',
#   'iman',
#   'die',
#   'specie',
#   'extinct',
#   'country',
#   'humanity',
#   'wipe',
#   '60',
#   'animal',
#   'specie',
#   '1970',
#   '😥',
#   '💔',
#   'worldrhinoday2020',
#   'wedontdeservethisplanet',
#   'rhino',
#   'worldrhinoday',
#   'poaching',
#   'great',
#   'job',
#   'clean',
#   'environment',
#   'healthy',
#   'life',
#   '-PRON-',
#   'ignore',
#   'reality',
#   'ignore',
#   'consequence',
#   'ignore',
#   'reality',
#   'savefor',
#   'saveecosystem',
#   'savebiodiversity',
#   'savevegetation',
#   'savenaturesavelife',
#   'savenaturesaveearth',
#   '❤',
#   '️.',
#   'necessary',
#   'write',
#   'project',
#   'explain',
#   'another',
#   'climate',
#   'fact',
#   'show',
#   'impact',
#   'global',
#   'warming',
#   'accelerate',
#   'terrifying',
#   'rate',
#   'globalwarming',
#   'world',
#   'day',
#   'desertification',
#   'drought',
#   '💔',
#   '-PRON-',
#   'change',
#   'behaviour',
#   'save',
#   'mother',
#   'nature',
#   'pritiranjandash',
#   'hi',
#   'guyss',
#   'hope',
#   "doi'n",
#   '-PRON-',
#   'launch',
#   'youtube',
#   'channel',
#   'like',
#   'suscribe',
#   'share',
#   'neeed',
#   'support',
#   'amd',
#   'help',
#   'every',
#   'week',
#   'upload',
#   'video',
#   'relate',
#   'global',
#   'warming',
#   'solution',
#   'do',
#   'not',
#   'forget',
#   'suscribe',
#   'link',
#   'give',
#   'https://youtu.be/tbdludgosvs',
#   'youtube.com',
#   'global',
#   'warming',
#   'first',
#   'video',
#   '|',
#   'intro',
#   '|',
#   'global',
#   'warming',
#   'climate',
#   'change',
#   'save',
#   'animal',
#   '❣',
#   '️',
#   '😘',
#   'why',
#   'selfish',
#   '😡',
#   'be',
#   'humble',
#   '🌸',
#   'save',
#   'animal',
#   '❣',
#   '️.',
#   'teach',
#   'child',
#   'gardening',
#   'help',
#   'image',
#   'adapt',
#   'climate',
#   'change',
#   'a',
#   'man',
#   '8',
#   'year',
#   'old',
#   'elephant',
#   'baby',
#   'brutally',
#   'kill',
#   'recently',
#   '3',
#   'nation',
#   '3',
#   'story',
#   '1',
#   'reason',
#   'human',
#   'cruelty',
#   '2020',
#   'june',
#   '5',
#   'friday',
#   '-PRON-',
#   'wish',
#   'happy',
#   'world',
#   'environment',
#   'day',
#   'hope',
#   'responsive',
#   'environment',
#   'year',
#   'save',
#   'environment',
#   'save',
#   'life']}

# %% [markdown]
# ### Count all the lemmas (words) per page and Sum of all words per page

# %%
counters0 = {k: Counter(v) for k, v in lemmatized0.items()}
counters1 = {k: Counter(v) for k, v in lemmatized1.items()}
counters_pos2 = {k: Counter(v) for k, v in lemmatized2_pos.items()}
counters_neg2 = {k: Counter(v) for k, v in lemmatized2_neg.items()}

# %%
count_words0 = {k: sum([len(vv.split()) for vv in v]) for k, v in lemmatized0.items()}
count_words1 = {k: sum([len(vv.split()) for vv in v]) for k, v in lemmatized1.items()}
count_words_pos2 = {k: sum([len(vv.split()) for vv in v]) for k, v in lemmatized2_pos.items()}
count_words_neg2 = {k: sum([len(vv.split()) for vv in v]) for k, v in lemmatized2_neg.items()}

# %%
count_words0
# Out:
# {'cfact': 13069,
#  'ClimateChangeIsNatural': 981,
#  'iloveco2': 2067,
#  'ClimateChangeLIES': 859,
#  'australianclimatemadness': 2613,
#  'ClimateDepot': 5535,
#  'ccdispatch': 708,
#  'TheCO2Coalition': 3437,
#  'Global-Warming-Climate-Change-whatever-its-called-is-a-scam-241741379521': 298,
#  'Global-Climate-Scam-1392664020945768': 530,
#  'greenpeace.international': 1337,
#  'NASAClimateChange': 1553,
#  'bloomberggreen': 893,
#  'acespace': 986,
#  'ClimateChangeIsReal': 3889,
#  'climatereality': 841,
#  'ClimateChangeNews': 1160,
#  'NatureClimateChange': 1201,
#  'ClimateChangeCauses': 591,
#  'GlobalwarmingEva': 476}

# %% [markdown]
# ## Calculate scores
# ### simple score = how much is a page related to clima based on the last posts
#
# Jake prumerne/medianove skore maji inicialni stranky, ktere uz mame olabelovane --
# muze se ukazat, ze negativni stranky vykazuji obecne nizsi skore a pak se jich mene zahrne do souboru v nasledne selekci (coz pozorujeme! cca 50 neg vs. 250 pos)

# %%
keywords = ['climate', 'co2', 'change', 'warming', ]

# %%
def sort_by_score(l):
    return sorted(l, key=lambda x: x[1], reverse=True)

# %%
import statistics as stat

# %%
print((f"median word count: {stat.median(sorted([v for k, v in count_words0.items()]))}\n" + 
      f"mean word count: {sum([v for k,v in count_words0.items()]) / len(count_words0)}"))
# Out:
# median word count: 1073.0
# mean word count: 2151.2

# %%
print((f"median wc pos: {stat.median(sorted([v for k, v in count_words0.items() if k in pos]))}\n" + 
      f"mean wc pos: {sum([v for k,v in count_words0.items() if k in pos]) / len([k for k,v in count_words0.items() if k in pos])}"))
# Out:
# median wc pos: 1160
# mean wc pos: 1337.111111111111

# %%
print((f"median wc pos: {stat.median(sorted([v for k, v in count_words0.items() if k in neg]))}\n" + 
      f"mean wc pos: {sum([v for k,v in count_words0.items() if k in neg]) / len([k for k,v in count_words0.items() if k in neg])}"))
# Out:
# median wc pos: 2067
# mean wc pos: 3235.1111111111113

# %%
# TF-IDF / BM25
def calculate_scores(keywords, counts, count_words):
    ref_doc_len = stat.median(sorted([v for k,v in count_words.items()]))
    ret = []
    for k, v in counts.items():
        tf = sum([counts[k][key] for key in keywords])
        score = tf / (0.75 * count_words[k] / ref_doc_len) if count_words[k] > 0 else 0
        ret.append((k, score)) 
    return sort_by_score(ret)

# %%
init_scores = calculate_scores(keywords, counters0, count_words0)
init_scores
# Out:
# [('climatereality', 98.66666666666667),
#  ('ClimateChangeNews', 98.66666666666666),
#  ('Global-Climate-Scam-1392664020945768', 94.47798742138366),
#  ('NatureClimateChange', 90.53344435192895),
#  ('TheCO2Coalition', 84.08340607118612),
#  ('ccdispatch', 82.84934086629002),
#  ('australianclimatemadness', 77.74767189692562),
#  ('ClimateChangeCauses', 60.51889452904681),
#  ('iloveco2', 60.21673923560716),
#  ('acespace', 55.13725490196079),
#  ('ClimateChangeLIES', 49.965075669383005),
#  ('NASAClimateChange', 47.90384202618588),
#  ('ClimateDepot', 41.87317073170732),
#  ('ClimateChangeIsReal', 41.20202279934859),
#  ('GlobalwarmingEva', 39.07282913165266),
#  ('bloomberggreen', 33.64389697648377),
#  ('greenpeace.international', 31.031662926950883),
#  ('Global-Warming-Climate-Change-whatever-its-called-is-a-scam-241741379521',
#   28.80536912751678),
#  ('cfact', 23.53610324686918),
#  ('ClimateChangeIsNatural', 7.291879034998301)]

# %%
print((f"median score pos: {stat.median(sorted([v for k, v in init_scores if k in pos]))}\n" + 
      f"mean score pos: {sum([v for k,v in init_scores if k in pos]) / len([k for k,v in init_scores if k in pos])}"))
# Out:
# median score pos: 55.13725490196079
# mean score pos: 62.525920444489756

# %%
print((f"median score neg: {stat.median(sorted([v for k, v in init_scores if k in neg]))}\n" + 
      f"mean score neg: {sum([v for k,v in init_scores if k in neg]) / len([k for k,v in init_scores if k in neg])}"))
# Out:
# median score neg: 60.21673923560716
# mean score neg: 60.394984918540985

# %% [markdown]
# ### Pos stranky jsou takove, na ktere se dostanu, kdyz zacnu v nektere z pozitivnich korenovych stranek a naopak pro negativni a neg label.

# %%
def get_class(pos_pages, neg_pages, pages):
    clima_pos, clima_neg = [], []
    for p in pages:
        if p[0] not in (pos_pages + neg_pages):
            print("Missing page ", page)
        if p[0] in pos_pages:
            clima_pos.append(p[0])
        if p[0] in neg_pages:
            clima_neg.append(p[0])
    return clima_pos, clima_neg

# %%
print(f"{len(pos_pages) + len(neg_pages)}\t{len(set(pos_pages + neg_pages))}")
# Out:
# 3755	3357

# %%
duplicates = (len(pos_pages) + len(neg_pages) - len(set(pos_pages + neg_pages))) / 2
print(f"There are about {duplicates} pages in both pos and neg.")
# Out:
# There are about 199.0 pages in both pos and neg.

# %%
clima, nclima = [], []
prev_cl, prev_ncl = 0, 0
THRESHOLD = 20
for counts, count_words, name in zip([counters0, counters1, counters_pos2, counters_neg2], 
                                       [count_words0, count_words1, count_words_pos2, count_words_neg2], 
                                       ['root', '1', '2-pos', '2-neg']):
    tmp_clima, tmp_nclima = [], []
    scores = calculate_scores(keywords, counts, count_words)    
    for page, sc in scores:
        if page in selected_pages:
            if sc < THRESHOLD:  # is clima / nonclima
                nclima.append((page, sc))
                tmp_nclima.append((page, sc))
            else:
                clima.append((page, sc))
                tmp_clima.append((page, sc))
            
    print(f"{name}:\t        clima: {len(clima) - prev_cl}\t\tnon-clima: {len(nclima) - prev_ncl}")
    proclima, anticlima = get_class(pos_pages, neg_pages, tmp_clima)
    print(f"\tproclima: {len(proclima)}\tanticlima: {len(anticlima)}\n")
    # proclima + anticlima != clima protoze nektere stranky jsou v pos i neg 
    # (dostanu se na ne z obou root class)
    # cisla 2-pos / 2-neg nenesou informaci o relaci. tzn nejsem si jisty, zda lze uplatnit ve smysli 2-neg
    # vidim vice anticlima stranek u 2-neg musi tam byt neco na strane algoritmu - pro neg doporucuje casteji neg
    # to nelze rici - mel jsem spatne pos/neg splity pri generovani a vztahy bude lepsi pocitat az na celem grafu potom
    prev_cl = len(clima)
    prev_ncl = len(nclima)
# Out:
# root:	        clima: 18		non-clima: 0
# 	proclima: 9	anticlima: 9
#
# 1:	        clima: 68		non-clima: 188
# 	proclima: 55	anticlima: 41
#
# 2-pos:	        clima: 217		non-clima: 887
# 	proclima: 211	anticlima: 92
#
# 2-neg:	        clima: 47		non-clima: 399
# 	proclima: 8	anticlima: 47

# %%
print(f"CLIMA: {len(clima)}\nNON-CLIMA: {len(nclima)}")
# Out:
# CLIMA: 350
# NON-CLIMA: 1474

# %% [markdown]
# ### Split the pages by its root page class - pro-clima / anti-clima

# %%
# print(f"pos: {len(proclima)}\tneg: {len(anticlima)}")

# %%
# len(set(proclima + anticlima))

# %% [markdown]
# ### Save output

# %%
with open('to-josef', 'w') as fw:
    for i in sorted(list(set(proclima + anticlima))):
        if i.strip:
            fw.write('https://www.facebook.com/' + i.strip() + '\n')

# %%
## create a single column of pagenames
with open('data/data2-uniq.csv', 'r') as f:
    with open('data/to-be-scraped-neg', 'w') as fw:
        for l in f.readlines():
            p = l.split(';')[0]
            if p in clima_neg:
                for page in l.split(';')[1:]:
                    if page.strip():
                        fw.write(f"{page.strip()}\n")
